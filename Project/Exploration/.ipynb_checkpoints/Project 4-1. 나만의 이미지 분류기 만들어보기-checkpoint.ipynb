# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import tensorflow as tf
import tensorflow_datasets as tfds
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# # 데이터셋 선택하기

# %%
(raw_train, raw_validation, raw_test), metadata = tfds.load(
    'tf_flowers',
    split=['train[:80%]', 'train[80%:90%]', 'train[90%:]'],
    with_info=True,
    as_supervised=True,
)

# %%
print(raw_train)
print(raw_validation)
print(raw_test)
# Out:
# <PrefetchDataset shapes: ((None, None, 3), ()), types: (tf.uint8, tf.int64)>
# <PrefetchDataset shapes: ((None, None, 3), ()), types: (tf.uint8, tf.int64)>
# <PrefetchDataset shapes: ((None, None, 3), ()), types: (tf.uint8, tf.int64)>

# %% [markdown]
# # 데이터셋을 모델에 넣을 수 있는 형태로 준비하기

# %%
IMG_SIZE = 160 # All images will be resized to 160x160

def format_example(image, label):
    image = tf.cast(image, tf.float32)  # image=float(image)같은 타입캐스팅의  텐서플로우 버전입니다.
    image = (image/127.5) - 1
    image = tf.image.resize(image, (IMG_SIZE, IMG_SIZE))
    return image, label

# %%
train = raw_train.map(format_example)
validation = raw_validation.map(format_example)
test = raw_test.map(format_example)

# %%
plt.figure(figsize=(10, 5))


get_label_name = metadata.features['label'].int2str

for idx, (image, label) in enumerate(train.take(10)):
    plt.subplot(2, 5, idx+1)
    image = (image + 1) / 2
    plt.imshow(image)
    plt.title(f'label {label}: {get_label_name(label)}')
    plt.axis('off')

# %% [markdown]
# # 모델 설계하기

# %% [markdown]
# ## 파라미터를 설정합니다.

# %%
BATCH_SIZE = 32
SHUFFLE_BUFFER_SIZE = 1000

# %% [markdown]
# ## 전체 데이터에서 32개를 랜덤으로 뽑음

# %%
train_batches = train.shuffle(SHUFFLE_BUFFER_SIZE).batch(BATCH_SIZE)
validation_batches = validation.batch(BATCH_SIZE)
test_batches = test.batch(BATCH_SIZE)

# %% [markdown]
# ## train_batches에서 하나의 batch만 꺼내봄

# %%
for image_batch, label_batch in train_batches.take(1):
    pass

image_batch.shape, label_batch.shape
# Out:
# (TensorShape([32, 160, 160, 3]), TensorShape([32]))

# %% [markdown]
# ## VGG16을 가져온다.

# %%
IMG_SHAPE = (IMG_SIZE, IMG_SIZE, 3)

# Create the base model from the pre-trained model VGG16
base_model = tf.keras.applications.VGG19(input_shape=IMG_SHAPE,
                                         include_top=False,
                                         weights='imagenet')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80142336/80134624 [==============================] - 10s 0us/step

# %% [markdown]
# ## 넣기전 사이즈를 확인한다.

# %%
image_batch.shape
# Out:
# TensorShape([32, 160, 160, 3])

# %% [markdown]
# ## 모델에 넣은 후 사이즈를 확인한다.

# %%
feature_batch = base_model(image_batch)
feature_batch.shape
# Out:
# TensorShape([32, 5, 5, 512])

# %%
base_model.summary()
# Out:
# Model: "vgg19"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 160, 160, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 160, 160, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 160, 160, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 80, 80, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 80, 80, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 80, 80, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 40, 40, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 40, 40, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 40, 40, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 40, 40, 256)       590080
# _________________________________________________________________
# block3_conv4 (Conv2D)        (None, 40, 40, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 20, 20, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 20, 20, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 20, 20, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 20, 20, 512)       2359808
# _________________________________________________________________
# block4_conv4 (Conv2D)        (None, 20, 20, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 10, 10, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 10, 10, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 10, 10, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 10, 10, 512)       2359808
# _________________________________________________________________
# block5_conv4 (Conv2D)        (None, 10, 10, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 5, 5, 512)         0
# =================================================================
# Total params: 20,024,384
# Trainable params: 20,024,384
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Classifier 부분을 채워준다.

# %%
global_average_layer = tf.keras.layers.GlobalAveragePooling2D()
feature_batch_average = global_average_layer(feature_batch)

# %%
dense_layer = tf.keras.layers.Dense(512, kernel_regularizer=tf.keras.regularizers.l2(0.001), activation='relu')
dropout= tf.keras.layers.Dropout(0.2)
prediction_layer = tf.keras.layers.Dense(5, activation='softmax')

# %%
#prediction_batch = prediction_layer(dense_layer(dropout(feature_batch_average)))

# %%
base_model.trainable = False

# %%
model = tf.keras.Sequential([
  base_model,
  global_average_layer,
  dense_layer,
  dropout,
  dense_layer,
  dropout,
  prediction_layer
])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg19 (Model)                (None, 5, 5, 512)         20024384
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 512)               0
# _________________________________________________________________
# dense (Dense)                (None, 512)               262656
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 5)                 2565
# =================================================================
# Total params: 20,289,605
# Trainable params: 265,221
# Non-trainable params: 20,024,384
# _________________________________________________________________

# %% [markdown]
# # 모델 학습시키기

# %% [markdown]
# ## 모델 컴파일 하기

# %%
base_learning_rate = 0.0001
model.compile(optimizer=tf.keras.optimizers.Nadam(lr=base_learning_rate),
              loss=tf.keras.losses.sparse_categorical_crossentropy,
              metrics=['accuracy'])

# %% [markdown]
# ## 학습시키기

# %%
EPOCHS = 20

history = model.fit(train_batches,
                    epochs=EPOCHS,
                    validation_data=validation_batches)
# Out:
# Epoch 1/20
# 92/92 [==============================] - 55s 603ms/step - loss: 1.9736 - accuracy: 0.3896 - val_loss: 1.7086 - val_accuracy: 0.6185
# Epoch 2/20
# 92/92 [==============================] - 10s 108ms/step - loss: 1.5730 - accuracy: 0.6253 - val_loss: 1.3488 - val_accuracy: 0.7139
# Epoch 3/20
# 92/92 [==============================] - 10s 107ms/step - loss: 1.3280 - accuracy: 0.6989 - val_loss: 1.1833 - val_accuracy: 0.7602
# Epoch 4/20
# 92/92 [==============================] - 10s 108ms/step - loss: 1.2050 - accuracy: 0.7221 - val_loss: 1.1080 - val_accuracy: 0.7711
# Epoch 5/20
# 92/92 [==============================] - 10s 107ms/step - loss: 1.1396 - accuracy: 0.7371 - val_loss: 1.0609 - val_accuracy: 0.7738
# Epoch 6/20
# 92/92 [==============================] - 10s 109ms/step - loss: 1.0748 - accuracy: 0.7589 - val_loss: 1.0464 - val_accuracy: 0.7902
# Epoch 7/20
# 92/92 [==============================] - 10s 109ms/step - loss: 1.0338 - accuracy: 0.7708 - val_loss: 1.0099 - val_accuracy: 0.8038
# Epoch 8/20
# 92/92 [==============================] - 10s 108ms/step - loss: 0.9848 - accuracy: 0.7844 - val_loss: 0.9911 - val_accuracy: 0.7984
# Epoch 9/20
# 92/92 [==============================] - 10s 108ms/step - loss: 0.9695 - accuracy: 0.7847 - val_loss: 0.9960 - val_accuracy: 0.7984
# Epoch 10/20
# 92/92 [==============================] - 10s 109ms/step - loss: 0.9391 - accuracy: 0.8011 - val_loss: 0.9539 - val_accuracy: 0.8093
# Epoch 11/20
# 92/92 [==============================] - 10s 109ms/step - loss: 0.9196 - accuracy: 0.8048 - val_loss: 0.9482 - val_accuracy: 0.8065
# Epoch 12/20
# 92/92 [==============================] - 10s 109ms/step - loss: 0.8965 - accuracy: 0.8072 - val_loss: 0.9359 - val_accuracy: 0.8147
# Epoch 13/20
# 92/92 [==============================] - 10s 110ms/step - loss: 0.8809 - accuracy: 0.8052 - val_loss: 0.9211 - val_accuracy: 0.8093
# Epoch 14/20
# 92/92 [==============================] - 10s 108ms/step - loss: 0.8562 - accuracy: 0.8246 - val_loss: 0.9315 - val_accuracy: 0.8011
# Epoch 15/20
# 92/92 [==============================] - 10s 108ms/step - loss: 0.8401 - accuracy: 0.8300 - val_loss: 0.9009 - val_accuracy: 0.8065
# Epoch 16/20
# 92/92 [==============================] - 10s 108ms/step - loss: 0.8268 - accuracy: 0.8311 - val_loss: 0.9067 - val_accuracy: 0.8147
# Epoch 17/20
# 92/92 [==============================] - 10s 108ms/step - loss: 0.8072 - accuracy: 0.8341 - val_loss: 0.8728 - val_accuracy: 0.8174
# Epoch 18/20
# 92/92 [==============================] - 10s 108ms/step - loss: 0.7952 - accuracy: 0.8413 - val_loss: 0.8627 - val_accuracy: 0.8174
# Epoch 19/20
# 92/92 [==============================] - 10s 108ms/step - loss: 0.7860 - accuracy: 0.8369 - val_loss: 0.8604 - val_accuracy: 0.8120
# Epoch 20/20
# 92/92 [==============================] - 10s 109ms/step - loss: 0.7655 - accuracy: 0.8392 - val_loss: 0.8574 - val_accuracy: 0.8256

# %% [markdown]
# # 모델 성능 평가하기

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize=(16, 8))
plt.subplot(1, 2, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.ylim([0,1.0])
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()

# %%
for image_batch, label_batch in test_batches.take(1):
    images = image_batch
    labels = label_batch
    predictions = model.predict(image_batch)
    pass

predictions

# %%
predictions = np.argmax(predictions, axis=1)
predictions

# %%
plt.figure(figsize=(20, 12))

for idx, (image, label, prediction) in enumerate(zip(images, labels, predictions)):
    plt.subplot(4, 8, idx+1)
    image = (image + 1) / 2
    plt.imshow(image)
    correct = label == prediction
    title = f'real: {label} / pred :{prediction}\n {correct}!'
    if not correct:
        plt.title(title, fontdict={'color': 'red'})
    else:
        plt.title(title, fontdict={'color': 'blue'})
    plt.axis('off')

# %% [markdown]
# # 모델 활용하기

# %% [markdown]
# # 마무리

# %% [markdown]
# ## 기본 결과

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 위의 그래프는 개선 내용의 기준이 되는 그래프입니다.
# 현재 결과는 accuracy: 0.7929, val_accuracy: 0.7575로 80%를 넘지 못합니다.
# 그래서 정확도를 높이기 위한 방법을 실험적으로 찾아보았습니다.
# 그리고 알게 된 사실이 커널을 새로 시작하면 결과가 바뀐다는 것이 었습니다.
# 그래서 변경 사항이 추가될 때 마다 커널을 Restart 했습니다.

# %% [markdown]
# ## 파라미터 변경

# %% [markdown]
# ### epoch = 10의 경우

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# epoch을 10으로 늘렸더니 성능이 개선 됨이 보였습니다.
# 결과는 accuracy: 0.8283 val_accuracy: 0.7956 입니다.

# %% [markdown]
# ## 드랍아웃 적용

# %% [markdown]
# ### epoch = 10인 경우

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# epoch이 10인 경우 Dense layer 사이에 dropout(0.2)를 적용 했더니 생각보다 눈에 뛰는 결과는 아니었습니다.      하지만 epoch의 수를 늘린다면 더 좋은 성능을 얻을 것 이라는 생각을 했습니다.
# 결과는 accuracy: 0.8096, val_accuracy: 0.7956입니다.

# %% [markdown]
# ### epoch = 20인 경우

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# epoch를 20으로 늘린 결과 점점 정확도가 증가하는게 보였습니다.
# 드롭아웃을 적용해서 그런지 Overfitting이 되지 않고
# 학습 횟수가 높을 수록 좋은 성능을 낸다는 것을 알게되었습니다.
# 결과는 accuracy: 0.8542 , val_accuracy: 0.8256 이었습니다.
# 최종 모델에서는 에폭을 20으로 늘려보기로 결정 했습니다.

# %% [markdown]
# ## Optimizer 변경

# %% [markdown]
# ### Adam의 경우

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 생각보다 결과가 좋지 않았았습니다.
# 결과는 accuracy: 0.7759, val_accuracy: 0.7520 입니다.

# %% [markdown]
# ### Nadam의 경우

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 결과는 accuracy: 0.7844, val_accuracy: 0.7711으로 기존 모델보다 조금 좋아보입니다.
# 최종 모델에서는 Nadam을 사용하겠습니다.

# %% [markdown]
# ## L2 regularization 적용

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Dense 레이어에 L2 regularization을 적용시켰습니다.
# 결과는 accuracy: 0.7779, val_accuracy: 0.7684로 기존 모델보다 조금 좋아졌습니다.

# %% [markdown]
# ## Dense layer 추가

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 결과는 accuracy: 0.7943, val_accuracy: 0.7629로 기존 모델보다 조금 좋아졌습니다.
# 이것도 결과 모델에 추가할 것입니다.

# %% [markdown]
# ## VGG16 최종 모델

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 결과는 accuracy: 0.8590, val_accuracy: 0.8365 상당한 발전을 이뤄냈습니다.
# 다른 모델을 쓰면 어떻게 되는 지도 궁금해 졌습니다.

# %% [markdown]
# ## VGG19 최종 모델

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 결과는 accuracy: 0.8392 - val_loss: 0.8574 - val_accuracy: 0.8256이다.
# 성능은 괜찮았지만 아래 사진을 보면 성능을 많이 잡아 먹는 것을 볼 수 있다.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## ResNet50 최종 모델

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 결과는 accuracy: 0.6625, val_accuracy: 0.6213이고 생각보다 성능이 좋지 않았다.
# 하지만 학습 속도는 VGG16보다 좋았다.
