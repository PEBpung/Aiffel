# %% [markdown]
# # 파이썬 크롤링 라이브러리

# %% [markdown]
# ## 파이썬 표준 라이브러리 urllib 사용하기

# %% [markdown]
# ### 웹페이지 다운로드

# %%
import urllib
def download(url):
    return urllib.request.urlopen(url)

# %% [markdown]
# urlopen()함수를 통해 해당 서버에서 요청받은 ("HTTPResponse")객체를 반환 합니다.
# 이 함수의 문제점은 웹페이지를 다운로드할 때 제어할 수 없는 에러가 발생할 수 있다는 점이에요.

# %%
from urllib.error import URLError, HTTPError, ContentTooShortError

def download(url):
    try:
        html = urllib.request.urlopen(url)
    except (URLError, HTTPError, ContentTooShortError) as e:
        print('Download error', e.reason)
        html = None
    return html

download('https://www.google.com')

# %% [markdown]
# 예외가 발생하는 경우를 확인하여 예외처리 코드를 추가시켜줍니다.

# %%
def download(url):
    try:
        html = urllib.request.urlopen(url).read()
    except (URLError, HTTPError, ContentTooShortError) as e:
        print('Download error', e.reason)
        html = None
    return html

# %% [markdown]
# ### 웹페이지 분석하기

# %% [markdown]
# 웹 페이지를 분석하기 위해선 HTML 사이의 데이터를 파싱해서 가져와야 합니다.
# 그리고 이 데이터를 가져오는 방법은 urlopen()의 read()메소드를 이용하는 거에요.

# %%
def download(url):
    try:
        html = urllib.request.urlopen(url).read()
    except (URLError, HTTPError, ContentTooShortError) as e:
        print('Download error', e.reason)
        html = None
    return html

# %%
download('https://www.google.com')
# Out:
# b'<!doctype html><html itemscope="" itemtype="http://schema.org/WebPage" lang="ko"><head><meta content="text/html; charset=UTF-8" http-equiv="Content-Type"><meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"><title>Google</title><script nonce="gbMaAqYzKEHXl9+lLj0auw==">(function(){window.google={kEI:\'n8c8X8rAGaa1mAWFx7ygBA\',kEXPI:\'0,202123,3,4,32,4,30,1151550,5663,731,223,756,4349,206,3204,10,1226,364,1499,611,206,383,246,5,1354,648,653,1661,1138,314,3,507,36,507,91,41,152,894,86,95,9,164,302,291,247,1119927,1197721,329546,13677,4855,32691,15248,867,17444,11240,9188,8384,4858,1362,9291,3022,4745,6,11027,1808,4020,978,7931,5297,2054,920,873,1217,9405,14528,234,4283,1396,1383,917,2277,8,2796,1593,1279,2212,239,291,149,1103,840,517,1522,4258,312,1137,2,2063,606,2025,2295,1947,245,1984,93,328,1284,16,2927,2246,1813,1787,2273,1,953,1989,856,7,6068,6285,4456,641,2449,3685,1742,4929,108,2855,552,908,2,971,684,1900,2397,7468,2179,1098,3,346,230,970,865,4624,149,189,2838,474,743,1299,8,441,2249,3943,47,1744,4,499,1029,702,1602,1236,271,874,405,1860,2393,1791,52,1416,961,463,460,120,1223,212,4067,154,882,1229,86,3,3280,1426,69,2033,387,195,2811,1409,344,690,1968,416,129,119,3390,189,320,200,23,887,256,308,126,563,102,273,4,51,31,469,834,76,683,337,1190,181,222,152,504,659,23,1757,650,278,62,52,535,92,157,229,761,55,1204,1391,70,13,992,849,13,425,2,308,489,219,6,516,103,13,219,111,336,958,475,2,13,79,3,666,160,4,6,107,445,113,861,666,43,140,63,8,252,1388,956,101,187,940,999,5771443,3522,21,8798372,549,333,444,1,2,80,1,900,896,1,9,2,2551,1,748,141,59,736,563,1,4265,1,1,2,1017,9,305,3299,248,416,111,2,19,4,3,8,11,4,2,9,1,1,1,32,1,2,5,3501565,20458660,2704830\',kBL:\'nio4\'};google.sn=\'webhp\';google.kHL=\'ko\';})();(function(){google.lc=[];google.li=0;google.getEI=function(a){for(var c;a&&(!a.getAttribute||!(c=a.getAttribute("eid")));)a=a.parentNode;return c||google.kEI};google.getLEI=function(a){for(var c=null;a&&(!a.getAttribute||!(c=a.getAttribute("leid")));)a=a.parentNode;return c};google.ml=function(){return null};google.time=function(){return Date.now()};google.log=function(a,c,b,d,g){if(b=google.logUrl(a,c,b,d,g)){a=new Image;var e=google.lc,f=google.li;e[f]=a;a.onerror=a.onload=a.onabort=function(){delete e[f]};google.vel&&google.vel.lu&&google.vel.lu(b);a.src=b;google.li=f+1}};google.logUrl=function(a,c,b,d,g){var e="",f=google.ls||"";b||-1!=c.search("&ei=")||(e="&ei="+google.getEI(d),-1==c.search("&lei=")&&(d=google.getLEI(d))&&(e+="&lei="+d));d="";!b&&google.cshid&&-1==c.search("&cshid=")&&"slh"!=a&&(d="&cshid="+google.cshid);b=b||"/"+(g||"gen_204")+"?atyp=i&ct="+a+"&cad="+c+e+f+"&zx="+google.time()+d;/^http:/i.test(b)&&"https:"==window.location.protocol&&(google.ml(Error("a"),!1,{src:b,glmm:1}),b="");return b};}).call(this);(function(){google.y={};google.x=function(a,b){if(a)var c=a.id;else{do c=Math.random();while(google.y[c])}google.y[c]=[a,b];return!1};google.lm=[];google.plm=function(a){google.lm.push.apply(google.lm,a)};google.lq=[];google.load=function(a,b,c){google.lq.push([[a],b,c])};google.loadAll=function(a,b){google.lq.push([a,b])};}).call(this);google.f={};(function(){\ndocument.documentElement.addEventListener("submit",function(b){var a;if(a=b.target){var c=a.getAttribute("data-submitfalse");a="1"==c||"q"==c&&!a.elements.q.value?!0:!1}else a=!1;a&&(b.preventDefault(),b.stopPropagation())},!0);document.documentElement.addEventListener("click",function(b){var a;a:{for(a=b.target;a&&a!=document.documentElement;a=a.parentElement)if("A"==a.tagName){a="1"==a.getAttribute("data-nohref");break a}a=!1}a&&b.preventDefault()},!0);}).call(this);\nvar a=window.location,b=a.href.indexOf("#");if(0<=b){var c=a.href.substring(b+1);/(^|&)q=/.test(c)&&-1==c.indexOf("#")&&a.replace("/search?"+c.replace(/(^|&)fp=[^&]*/g,"")+"&cad=h")};</script><style>#gbar,#guser{font-size:13px;padding-top:1px !important;}#gbar{height:22px}#guser{padding-bottom:7px !important;text-align:right}.gbh,.gbd{bord ...

# %% [markdown]
# 자 이 데이터를 어떻게 파싱할까요? 문자열 함수..정규표현식을 이용하면 되는데.. 이 2가지만 가지고 분석하기에는…네 너무 힘듭니다.

# %% [markdown]
# ## 파이썬 라이브러리 BeautifulSoup, Requests 사용하기

# %% [markdown]
# ### 웹페이지 다운로드

# %% [markdown]
# requests의 get()메소드를 이용하여 웹페이지를 다운로드 받을 수 있습니다.

# %%
import requests
url = 'http://www.google.com'
response = requests.get(url)
response
# Out:
# <Response [200]>

# %% [markdown]
# STEP1-1에서 HTTP의 Response 관련 메소드에 2xx는 응답관련 메소드라고 했습니다. 200은 응답에 성공이란 뜻이에요.
# 응답에 성공하면, 이어서 get()메소드의 text 멤버변수에 접근 할 수 있는데요, text는 HTML을 반환합니다. 다음은 예외처리를 한 코드에요

# %%
def download2(url):
    try:
        response = requests.get(url)
        html = response.text
    except requests.ConnectionError:
        print('Connection error')
        html = None
    return html

download2('https://www.google.com')
# Out:
# '<!doctype html><html itemscope="" itemtype="http://schema.org/WebPage" lang="ko"><head><meta content="text/html; charset=UTF-8" http-equiv="Content-Type"><meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"><title>Google</title><script nonce="EU9/xo/DILKcNJ0RQ2qk6A==">(function(){window.google={kEI:\'Gsg8X_zwF5jZz7sPxpa2wA8\',kEXPI:\'0,202123,3,4,32,4,30,570823,580727,5663,731,223,5104,207,3204,10,1226,364,1499,611,206,383,246,5,1015,339,648,3451,315,3,374,134,543,89,42,152,864,30,84,106,163,427,167,227,217,41,7,1119682,1197759,329508,13677,4855,32691,15248,861,17450,11240,9188,8384,4858,1362,9291,3021,2822,1924,8000,3033,1808,4020,978,7931,5297,2054,920,873,1217,2975,6430,7432,7095,4517,1399,1379,919,2279,7,2795,885,708,1279,2212,530,149,1103,840,517,1522,4258,109,203,1137,2,2063,606,2023,1777,520,1947,2229,93,328,1284,16,2927,2247,1812,1787,3227,2845,7,5599,469,6286,4455,641,2449,3685,1742,4929,108,3407,908,2,941,2614,2397,7470,2177,1098,3,576,970,865,4624,149,189,2838,475,2488,2251,1992,1998,83,1661,4,1528,1674,630,1236,271,874,405,1860,1816,577,1791,52,1416,961,464,459,118,1224,213,3,5100,1228,87,3,3280,1426,69,2615,2525,34,252,1753,690,1968,416,125,124,3389,189,320,198,25,887,254,310,689,102,275,10,44,30,1303,76,680,341,1191,178,83,140,152,504,90,569,23,481,17,519,529,211,650,340,52,535,89,160,991,1255,256,1140,103,970,346,499,4,13,1443,6,515,104,13,330,336,958,342,133,2,14,82,492,333,4,6,108,443,1642,245,8,1449,1145,102,1129,5772440,1874,1652,5996522,2801868,549,333,444,1,2,80,1,900,896,6,4,2,2551,1,748,141,59,736,563,1,4265,1,1,2,1017,9,305,3299,248,415,112,2,19,4,2,8,11,5,2,9,1,1,1,32,1,2,5,3501565,20458660,2701891,5542,3\',kBL:\'vHaf\'};google.sn=\'webhp\';google.kHL=\'ko\';})();(function(){google.lc=[];google.li=0;google.getEI=function(a){for(var c;a&&(!a.getAttribute||!(c=a.getAttribute("eid")));)a=a.parentNode;return c||google.kEI};google.getLEI=function(a){for(var c=null;a&&(!a.getAttribute||!(c=a.getAttribute("leid")));)a=a.parentNode;return c};google.ml=function(){return null};google.time=function(){return Date.now()};google.log=function(a,c,b,d,g){if(b=google.logUrl(a,c,b,d,g)){a=new Image;var e=google.lc,f=google.li;e[f]=a;a.onerror=a.onload=a.onabort=function(){delete e[f]};google.vel&&google.vel.lu&&google.vel.lu(b);a.src=b;google.li=f+1}};google.logUrl=function(a,c,b,d,g){var e="",f=google.ls||"";b||-1!=c.search("&ei=")||(e="&ei="+google.getEI(d),-1==c.search("&lei=")&&(d=google.getLEI(d))&&(e+="&lei="+d));d="";!b&&google.cshid&&-1==c.search("&cshid=")&&"slh"!=a&&(d="&cshid="+google.cshid);b=b||"/"+(g||"gen_204")+"?atyp=i&ct="+a+"&cad="+c+e+f+"&zx="+google.time()+d;/^http:/i.test(b)&&"https:"==window.location.protocol&&(google.ml(Error("a"),!1,{src:b,glmm:1}),b="");return b};}).call(this);(function(){google.y={};google.x=function(a,b){if(a)var c=a.id;else{do c=Math.random();while(google.y[c])}google.y[c]=[a,b];return!1};google.lm=[];google.plm=function(a){google.lm.push.apply(google.lm,a)};google.lq=[];google.load=function(a,b,c){google.lq.push([[a],b,c])};google.loadAll=function(a,b){google.lq.push([a,b])};}).call(this);google.f={};(function(){\ndocument.documentElement.addEventListener("submit",function(b){var a;if(a=b.target){var c=a.getAttribute("data-submitfalse");a="1"==c||"q"==c&&!a.elements.q.value?!0:!1}else a=!1;a&&(b.preventDefault(),b.stopPropagation())},!0);document.documentElement.addEventListener("click",function(b){var a;a:{for(a=b.target;a&&a!=document.documentElement;a=a.parentElement)if("A"==a.tagName){a="1"==a.getAttribute("data-nohref");break a}a=!1}a&&b.preventDefault()},!0);}).call(this);\nvar a=window.location,b=a.href.indexOf("#");if(0<=b){var c=a.href.substring(b+1);/(^|&)q=/.test(c)&&-1==c.indexOf("#")&&a.replace("/search?"+c.replace(/(^|&)fp=[^&]*/g,"")+"&cad=h")};</script><style>#gbar,#guser{font-size:13px;padding-top:1px !important;}#gbar{height:22px}#guser{padding-bottom:7px !important;text-align:right}.gbh,.gbd{border-top:1px solid #c ...

# %% [markdown]
# ### 웹페이지 분석하기

# %% [markdown]
# 웹페이지 다운로드를 BeautifulSoup객체로 만들어 줍니다.

# %%
import requests
from bs4 import BeautifulSoup
html = requests.get('http://www.google.com')
soup = BeautifulSoup(html.text, 'html.parser')

# %% [markdown]
# 그러면 html 태그를 클래스 변수를 이용해 접근할 수 있어요.

# %%
soup.html.body
# Out:
# <body bgcolor="#fff"><script nonce="m2gD0UaikQdZAFY26Fz4aw==">(function(){var src='/images/nav_logo229.png';var iesg=false;document.body.onload = function(){window.n && window.n();if (document.images){new Image().src=src;}
# if (!iesg){document.f&&document.f.q.focus();document.gbqf&&document.gbqf.q.focus();}
# }
# })();</script><div id="mngb"><div id="gbar"><nobr><b class="gb1">검색</b> <a class="gb1" href="http://www.google.co.kr/imghp?hl=ko&amp;tab=wi">이미지</a> <a class="gb1" href="http://maps.google.co.kr/maps?hl=ko&amp;tab=wl">지도</a> <a class="gb1" href="https://play.google.com/?hl=ko&amp;tab=w8">Play</a> <a class="gb1" href="http://www.youtube.com/?gl=KR&amp;tab=w1">YouTube</a> <a class="gb1" href="https://news.google.com/?tab=wn">뉴스</a> <a class="gb1" href="https://mail.google.com/mail/?tab=wm">Gmail</a> <a class="gb1" href="https://drive.google.com/?tab=wo">드라이브</a> <a class="gb1" href="https://www.google.co.kr/intl/ko/about/products?tab=wh" style="text-decoration:none"><u>더보기</u> »</a></nobr></div><div id="guser" width="100%"><nobr><span class="gbi" id="gbn"></span><span class="gbf" id="gbf"></span><span id="gbe"></span><a class="gb4" href="http://www.google.co.kr/history/optout?hl=ko">웹 기록</a> | <a class="gb4" href="/preferences?hl=ko">설정</a> | <a class="gb4" href="https://accounts.google.com/ServiceLogin?hl=ko&amp;passive=true&amp;continue=http://www.google.com/&amp;ec=%0000000" id="gb_70" target="_top">로그인</a></nobr></div><div class="gbh" style="left:0"></div><div class="gbh" style="right:0"></div></div><center><br clear="all" id="lgpd"/><div id="lga"><img alt="Google" height="92" id="hplogo" src="/images/branding/googlelogo/1x/googlelogo_white_background_color_272x92dp.png" style="padding:28px 0 14px" width="272"/><br/><br/></div><form action="/search" name="f"><table cellpadding="0" cellspacing="0"><tr valign="top"><td width="25%"> </td><td align="center" nowrap=""><input name="ie" type="hidden" value="ISO-8859-1"/><input name="hl" type="hidden" value="ko"/><input name="source" type="hidden" value="hp"/><input name="biw" type="hidden"/><input name="bih" type="hidden"/><div class="ds" style="height:32px;margin:4px 0"><div style="position:relative;zoom:1"><input autocomplete="off" class="lst tiah" maxlength="2048" name="q" size="57" style="margin:0;padding:5px 8px 0 6px;vertical-align:top;color:#000;padding-right:38px" title="Google 검색" value=""/><img alt="" data-script-url="/textinputassistant/11/ko_tia.js" height="23" id="tsuid1" src="/textinputassistant/tia.png" style="position:absolute;cursor:pointer;right:5px;top:4px;z-index:300" width="27"/><script nonce="m2gD0UaikQdZAFY26Fz4aw==">(function(){var id='tsuid1';document.getElementById(id).onclick = function(){var s = document.createElement('script');s.src = this.getAttribute('data-script-url');(document.getElementById('xjsc')||document.body).appendChild(s);};})();</script></div></div><br style="line-height:0"/><span class="ds"><span class="lsbb"><input class="lsb" name="btnG" type="submit" value="Google 검색"/></span></span><span class="ds"><span class="lsbb"><input class="lsb" id="tsuid2" name="btnI" type="submit" value="I’m Feeling Lucky"/><script nonce="m2gD0UaikQdZAFY26Fz4aw==">(function(){var id='tsuid2';document.getElementById(id).onclick = function(){if (this.form.q.value){this.checked = 1;if (this.form.iflsig)this.form.iflsig.disabled = false;}
# else top.location='/doodles/';};})();</script><input name="iflsig" type="hidden" value="AINFCbYAAAAAXzzWsCnpX7_yigKvIscdpysOkt00DeKA"/></span></span></td><td align="left" class="fl sblc" nowrap="" width="25%"><a href="/advanced_search?hl=ko&amp;authuser=0">고급검색</a></td></tr></table><input id="gbv" name="gbv" type="hidden" value="1"/><script nonce="m2gD0UaikQdZAFY26Fz4aw==">(function(){var a,b="1";if(document&&document.getElementById)if("undefined"!=typeof XMLHttpRequest)b="2";else if("undefined"!=typeof ActiveXObject){var c,d,e=["MSXML2.XMLHTTP.6.0","MSXML2.XMLHTTP.3.0","MSXML2.XMLHTTP","Microsoft.XMLHTTP"];for(c=0;d=e[c++];)try{new ActiveXObject(d),b="2"}catch(h){}}a=b;if("2"==a&&-1==location.search.indexOf("&gbv=2")){var f=google.gbvu,g=document.getElementById("gbv");g&&(g.value=a);f&&window.setTimeout(function(){location.href=f},0)};}).call(this);</script></form><div id="gac_scont"></div><div style="font-size:83%;min-height:3.5em"><br/></div><span id="footer"><div style="font-size:10pt"><div id="fll" style="margin:19px auto;text-align:center"><a href="/intl/ko/ads/">광고 프로그램</a><a href="http://www.google.co.kr/intl/ko/services/">비즈니스 솔루션</a><a href="/intl/ko/about.html">Google 정보</a><a href="http://www.google.com/setprefdomain?prefdom=KR&amp;prev=http://www.google.co.kr/&amp;sig=K_0azKeXdgQKxr2nrUvP59e1Cn_aw%3D">Google.co.kr</a></div></div><p style="font-size:8pt;color:#767676">© 2020 - <a href="/intl/ko/policies/privacy/">개인정보처리방침</a> - <a href="/intl/ko/policies/terms/">약관</a></p></span></center><script nonce="m2gD0UaikQdZAFY26Fz4aw==">(function(){window.google.cdo={height:0,width:0};(function(){var a=window.innerWidth,b=window.innerHeight;if(!a||!b){var c=window.document,d="CSS1Compat"==c.compatMode?c.documentElement:c.body;a=d.clientWidth;b=d.clientHeight}a&&b&&(a!=google.cdo.width||b!=google.cdo.height)&&google.log("","","/client_204?&atyp=i&biw="+a+"&bih="+b+"&ei="+google.kEI);}).call(this);})();(function(){var u='/xjs/_/js/k\x3dxjs.hp.en.pOAzb15qhrs.O/m\x3dsb_he,d/am\x3dAJ5gcw/d\x3d1/rs\x3dACT90oGDkPaV3sOFi_aQIWB3WuF0OUNb8g';
# setTimeout(function(){var b=document;var a="SCRIPT";"application/xhtml+xml"===b.contentType&&(a=a.toLowerCase());a=b.createElement(a);a.src=u;google.timers&&google.timers.load&&google.tick&&google.tick("load","xjsls");document.body.appendChild(a)},0);})();(function(){window.google.xjsu='/xjs/_/js/k\x3dxjs.hp.en.pOAzb15qhrs.O/m\x3dsb_he,d/am\x3dAJ5gcw/d\x3d1/rs\x3dACT90oGDkPaV3sOFi_aQIWB3WuF0OUNb8g';})();function _DumpException(e){throw e;}
# function _F_installCss(c){}
# (function(){google.jl={dw:false,em:[],emw:false,lls:'default',pdt:0,snet:true,uwp:true};})();(function(){var pmc='{\x22d\x22:{},\x22sb_he\x22:{\x22agen\x22:true,\x22cgen\x22:true,\x22client\x22:\x22heirloom-hp\x22,\x22dh\x22:true,\x22dhqt\x22:true,\x22ds\x22:\x22\x22,\x22ffql\x22:\x22ko\x22,\x22fl\x22:true,\x22host\x22:\x22google.com\x22,\x22isbh\x22:28,\x22jsonp\x22:true,\x22msgs\x22:{\x22cibl\x22:\x22&#44160;&#49353;&#50612; &#51648;&#50864;&#44592;\x22,\x22dym\x22:\x22&#51060;&#44163;&#51012; &#52286;&#51004;&#49512;&#45208;&#50836;?\x22,\x22lcky\x22:\x22I&#8217;m Feeling Lucky\x22,\x22lml\x22:\x22&#51088;&#49464;&#55176; &#50508;&#50500;&#48372;&#44592;\x22,\x22oskt\x22:\x22&#51077;&#47141; &#46020;&#44396;\x22,\x22psrc\x22:\x22&#44160;&#49353;&#50612;&#44032; \\u003Ca href\x3d\\\x22/history\\\x22\\u003E&#50937; &#44592;&#47197;\\u003C/a\\u003E&#50640;&#49436; &#49325;&#51228;&#46104;&#50632;&#49845;&#45768;&#45796;.\x22,\x22psrl\x22:\x22&#49325;&#51228;\x22,\x22sbit\x22:\x22&#51060;&#48120;&#51648;&#47196; &#44160;&#49353;\x22,\x22srch\x22:\x22Google &#44160;&#49353;\x22},\x22ovr\x22:{},\x22pq\x22:\x22\x22,\x22refpd\x22:true,\x22refspre\x22:true,\x22rfs\x22:[],\x22sbpl\x22:16,\x22sbpr\x22:16,\x22scd\x22:10,\x22stok\x22:\x22r8rzV0lHoyPSiWocDOJTlCGFGmU\x22,\x22uhde\x22:false}}';google.pmc=JSON.parse(pmc);})();</script> </body>

# %% [markdown]
# 예를들어, html이 태그 내용이 다음과 같다고 할께요,

# %%
soup = BeautifulSoup("<span>Wow it's so good!!</span>", 'html.parser')
soup.span
# Out:
# <span>Wow it's so good!!</span>

# %% [markdown]
# ### find(), findAll()

# %% [markdown]
# BeautifulSoup에서 제공하는 이 두 함수는 정말 자주 사용되는 함수입니다. 태그에 더 쉽게 접근할 수 있고 태그의 속성에 따라 필터링도 할 수 있어요.
# BeautifulSoup객체로 만든 뒤 p태그 항목을 찾는 코드는 다음과 같아요.

# %%
# ''', """ 는 여러줄의 문자열을 입력할 때 사용
html='''<title>Fundamental</title> 
         <body>
          <p id='programming'>python</p> 
          <p id='programming'>java</p> 
          <p id='algorithm'>algorithm</p> 
          <p id='fundamental'>math</p> 
          <p id='programming'>C++</p> 
          </body>'''
soup = BeautifulSoup(html, 'html.parser')
soup.findAll({'p'})
# Out:
# [<p id="programming">python</p>,
#  <p id="programming">java</p>,
#  <p id="algorithm">algorithm</p>,
#  <p id="fundamental">math</p>,
#  <p id="programming">C++</p>]

# %% [markdown]
# p태그에서 속성값이 programming인 태그를 찾고 싶을때는 다음과 같이 해주면 됩니다.

# %%
soup.findAll('p', id='programming')
# Out:
# [<p id="programming">python</p>,
#  <p id="programming">java</p>,
#  <p id="programming">C++</p>]

# %% [markdown]
# # 네이버 환율 정보 크롤링

# %%
import requests
url = 'https://m.stock.naver.com/marketindex/index.nhn'
response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
def download3(url):
    try:
        response = requests.get(url)
        html = response.text
    except requests.ConnectionError:
        print('Connection error')
        html = None
    return html

download3('https://m.stock.naver.com/marketindex/index.nhn')
# Out:
# '\n\n\n\n\n<!-- header -->\n\n\n\n\n\n\n\n\n<!doctype html>\n\n<html lang="ko">\n<head>\n    <meta charset="utf-8">\n    <meta name="viewport" content="width=device-width,initial-scale=1.0,maximum-scale=1.0,minimum-scale=1.0,user-scalable=no">\n\n    \n    \n        \n        \n            <meta property="og:url" content="http://m.stock.naver.com/marketindex/index.nhn?menu=exchange"/>\n            \n                \n                    <meta property="og:title" content="네이버 증권"/>\n                \n                \n            \n            \n                \n                    <meta property="og:description" content="관심종목의 실시간 주가를 가장 빠르게 확인하는 곳"/>\n                \n                \n            \n            \n                \n                    <meta property="og:image" content="https://ssl.pstatic.net/static/m/stock/im/2016/08/og_stock-200.png"/>\n                \n                \n            \n        \n    \n\n    <meta property="og:type" content="article"/>\n    <meta property="og:article:thumbnailUrl" content=""/>\n    <meta property="og:article:author" content="네이버증권"/>\n    <meta property="og:article:author:url" content="https://m.stock.naver.com"/>\n    \n\n    <title>네이버 증권</title>\n    <link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/imgstock/static.mobile/css/finance/min/20200814174313/mstock.css"/>\n\n    <!-- favicon -->\n    <link rel="shortcut icon" href="https://ssl.pstatic.net/imgstock/favicon.ico"/>\n\n    \n        \n        \n    \n\n    <script type="text/javascript">\n        var REQUEST_MOBILE_BROWSER_TYPE = "";\n        var REQUEST_TELEPHONE_CORPORATION = "";\n\n        var nsc="Mstock.market";\n        var ccsrv="cc.naver.com";\n    </script>\n\n    <script type="text/javascript" src="https://ssl.pstatic.net/imgstock/static.mobile/js/finance/min/20200814174313/header.js"></script>\n\n    <script type="text/javascript">\n\n\n        ;(function(){\n            var doc = document.documentElement;\n            doc.setAttribute(\'data-useragent\', navigator.userAgent);\n        })();\n    </script>\n</head>\n\n\n\n\n<body class="marketindex">\n\n\n\n<!-- u_skip -->\n<div class="u_skip" >\n    <a href="#content">본문 바로가기</a>\n</div>\n\n\n<header id="header" role="banner" class="home_header">\n    <!-- gnb -->\n    <div class="Ngnb">\n        <span class="Ngnb_logo"><a href="https://m.naver.com/" class="Nlogo_link"><span class="Nicon_logo">NAVER</span></a></span>\n        <div class="Ngnb_service">\n            <h1 class="Nservice_item"><a href="https://m.stock.naver.com/index.nhn"><span class="Nicon_service">증권</span></a></h1>\n        </div>\n\n        <div class="Ngnb_tool">\n            <a href="#" class="Ntool_button _btn_my" onclick="nclk(this, \'gnb.my\', \'\', \'\');"><span class="Nicon_my">MY</span></a>\n        </div>\n    </div>\n\n    <div class="pop_mylist _my_layer">\n    </div>\n    <!-- 검색 -->\n    <!-- 모바일 -->\n    <div class="Nsearch">\n        <div class="Nsearch_inner">\n            <div class="Nsearch_box">\n                <div class="Nsearch_box_inner">\n                    <form name="search" id="search" action="/searchItem.nhn" method="get" onsubmit="return delayed_submit(this)">\n                        <span class="Nbox_text"><input type="text" name="keyword_input" id="keyword_top" value="" placeholder="" title="검색어 입력" class="Nbox_input_text" onfocus="clearKeyword(this);" onblur="checkKeyword(this);"></span>\n                        <input type="hidden" name="keyword" />\n                        <input type="hidden" name="retUrl" value=""/>\n                        <span class="Nbox_tool">\n\t\t\t\t\t\t\t<button type="button" class="Nbox_button Nbox_delete" id="clearBtnTop" style="display: none;">\n\t\t\t\t\t\t\t\t<span class="Nicon_delete">검색어 삭제</span>\n\t\t\t\t\t\t\t</button>\n\t\t\t\t\t\t\t<button type="submit" class="Nbox_button Nbox_search" onclick="nclk(this, \'gnb.search\', \'\', \'\');">\n\t\t\t\t\t\t\t\t<span class="Nicon_submit">검색</span>\n\ ...

# %%
import requests
from bs4 import BeautifulSoup
html = requests.get('https://m.stock.naver.com/marketindex/index.nhn')
soup = BeautifulSoup(html.text, 'html.parser')

# %%
soup.html.body
# Out:
# <body class="marketindex">
# <!-- u_skip -->
# <div class="u_skip">
# <a href="#content">본문 바로가기</a>
# </div>
# <header class="home_header" id="header" role="banner">
# <!-- gnb -->
# <div class="Ngnb">
# <span class="Ngnb_logo"><a class="Nlogo_link" href="https://m.naver.com/"><span class="Nicon_logo">NAVER</span></a></span>
# <div class="Ngnb_service">
# <h1 class="Nservice_item"><a href="https://m.stock.naver.com/index.nhn"><span class="Nicon_service">증권</span></a></h1>
# </div>
# <div class="Ngnb_tool">
# <a class="Ntool_button _btn_my" href="#" onclick="nclk(this, 'gnb.my', '', '');"><span class="Nicon_my">MY</span></a>
# </div>
# </div>
# <div class="pop_mylist _my_layer">
# </div>
# <!-- 검색 -->
# <!-- 모바일 -->
# <div class="Nsearch">
# <div class="Nsearch_inner">
# <div class="Nsearch_box">
# <div class="Nsearch_box_inner">
# <form action="/searchItem.nhn" id="search" method="get" name="search" onsubmit="return delayed_submit(this)">
# <span class="Nbox_text"><input class="Nbox_input_text" id="keyword_top" name="keyword_input" onblur="checkKeyword(this);" onfocus="clearKeyword(this);" placeholder="" title="검색어 입력" type="text" value=""/></span>
# <input name="keyword" type="hidden">
# <input name="retUrl" type="hidden" value=""/>
# <span class="Nbox_tool">
# <button class="Nbox_button Nbox_delete" id="clearBtnTop" style="display: none;" type="button">
# <span class="Nicon_delete">검색어 삭제</span>
# </button>
# <button class="Nbox_button Nbox_search" onclick="nclk(this, 'gnb.search', '', '');" type="submit">
# <span class="Nicon_submit">검색</span>
# </button>
# </span>
# </input></form>
# </div>
# </div>
# </div>
# <!-- // 모바일 -->
# <div class="atcp" id="autocomplete_layer" style="display:none;">
# <div class="auto_lst">
# <ul>
# <li class="atcp_li" onclick="nclk(this, 'aut.list', '', '');"><a class="atcp_a" href="@in_link@" id="a_link"><span class="code">@code@</span><b class="stock_item">@txt@</b><span class="code2">@market@</span></a><input id="hidden_input" type="hidden" value="@in_name@"/></li>
# </ul>
# </div>
# </div>
# </div>
# <!-- // 검색 -->
# <!-- lnb -->
# <div class="Nlnb">
# <!-- 1depth -->
# <div class="Nlnb_menu">
# <div class="Nlnb_menu_inner">
# <ul class="Nlnb_menu_list" role="tablist">
# <!-- [D] 선택시 li에 is_active, aria-selected="true" 추가 -->
# <li class="Nlist_item" role="tab"><a class="Nitem_link" href="https://m.stock.naver.com/index.nhn" onclick="nclk(this, 'smn.home', '', '');"><span class="Nitem_link_menu">홈</span></a></li>
# <li class="Nlist_item" role="tab"><a class="Nitem_link" href="https://m.stock.naver.com/sise/siseList.nhn?menu=market_sum&amp;sosok=0" onclick="nclk(this, 'smn.local', '', '');"><span class="Nitem_link_menu">국내</span></a></li>
# <li class="Nlist_item" role="tab"><a class="Nitem_link" href="https://m.stock.naver.com/worldstock/index.html" onclick="nclk(this, 'smn.world', '', '');"><span class="Nitem_link_menu">해외</span></a></li>
# <li aria-selected="true" class="Nlist_item is_active" role="tab"><a class="Nitem_link" href="https://m.stock.naver.com/marketindex/index.nhn" onclick="nclk(this, 'smn.market', '', '');"><span class="Nitem_link_menu">시장지표</span></a></li>
# <li class="Nlist_item" role="tab"><a class="Nitem_link" href="https://m.stock.naver.com/news/index.nhn?category=mainnews" onclick="nclk(this, 'smn.news', '', '');"><span class="Nitem_link_menu">뉴스</span></a></li>
# <li class="Nlist_item" role="tab"><a class="Nitem_link" href="https://m.stock.naver.com/research/research.nhn" onclick="nclk(this, 'smn.strategy', '', '');"><span class="Nitem_link_menu">리서치</span></a></li>
# </ul>
# </div>
# </div>
# </div>
# <!-- // lnb -->
# </header>
# <script type="text/javascript">
#     function closeBanner() {
#         jindo.$Cookie().set('close_shortcut', 1, 14, window.location.host, '/');
#         jindo.$Element("bannerAdd").css("display", "none");
#     }
#
#     function createCookie() {
#         if(!jindo.$Cookie().get("add_shortcut")) {
#             jindo.$Cookie().set('add_shortcut', 1, 365, window.location.host, '/');
#             jindo.$Element("bannerAdd").css("display", "none");
#         }
#     }
#
#     function createMyCookie() {
#         if(!jindo.$Cookie().get("my_shortcut")) {
#             jindo.$Cookie().set('my_shortcut', 1, 365, window.location.host, '/');
#             jindo.$Element("myBannerAdd").css("display", "none");
#         }
#     }
#
#     function initAutoComplete(){
#         var oAutoComplete = null;
#
#         jindo.$("hidden_input").value = "@in_name@";
#         jindo.$("a_link").href = "@in_link@";
#
#
#         var acUrl = "https://";
#         if (location.hostname.indexOf("staging-") > -1) {
#             acUrl += "staging-";
#         } else if (location.hostname.indexOf("dev-") > -1 || location.hostname.indexOf("local-m") > -1) {
#             acUrl += "dev-";
#         }
#
#         acUrl += "ac.finance.naver.com/ac";
#
#         var htAcOption = {
#             sUrl				: acUrl,
#             sFormName			: "search",
#             nCutstr				: 60,
#             request_type        : "jsonp",
#             sType				: "search",
#             sClearBtn			: "clearBtnTop",
#             //sCloseBtn			: "close_input",
#             sQueryFormat		: "{query}",
#             sRequestType		: "jsonp",
#             aRedirectUrl : {
#                 itemmain:"/item/index.nhn",
#                 sisesise_index:"/sise/siseIndex.nhn",
#                 worldsise:"/world/item.nhn",
#                 marketindexsise:"/marketindex/item.nhn",
#                 marketindexmaterialDetail: "/marketindex/item.nhn",
#                 marketindexexchangeDetail: "/marketindex/item.nhn",
#                 marketindexworldGoldDetail: "/marketindex/item.nhn",
#                 marketindexworldExchangeDetail: "/marketindex/item.nhn"
#             },
#             htRequestFormat		: {q:"{query}",q_enc : "euc-kr",t_koreng:1,st:111,r_lt : 111}
#         };
#
#
#         window.oAutoComplete = new nhn.AutoCompleteMobile("keyword_top","autocomplete_layer",htAcOption).attach({
#
#             "onBlur"		: function() {
#             },
#
#             "onChangeInput"	: function() {
#             },
#
#             "onFocus"		: function() {
#             },
#
#             "actSubmit"		: function(aLink) {
#                 location.href = aLink;
#             },
#
#             "acShow"		: function() {
#             },
#
#             "acHide"		: function() {
#             }
#         });
#     }
# </script>
# <!-- //header -->
# <!-- ct -->
# <div class="reveal-contents" id="content" role="main" style="position:relative">
# <div class="ct_wrp">
# <h2 class="blind">시장지표</h2>
# <div class="ct_box intnl_major_item">
# <h3 class="blind">주요지수</h3>
# <ul class="international_lst">
# <li class="stock_dn">
# <a href="/marketindex/item.nhn?marketindexCd=FX_USDKRW&amp;menu=exchange" onclick="nclk(this, 'mim.index', '', '');">
# <div class="item_wrp">
# <strong class="stock_item">미국USD</strong><span class="time">08.19 15:32</span>
# </div>
# <div class="price_wrp">
# <span class="stock_price">1,181.50</span>
# <div class="gap_wrp">
# <span class="gap_price"><em class="ico">하락</em>3.00</span><span class="gap_rate">-0.25<span class="per">%</span></span>
# </div>
# </div>
# </a>
# </li>
# <li class="stock_up">
# <a href="/marketindex/item.nhn?marketindexCd=FX_EURKRW&amp;menu=exchange" onclick="nclk(this, 'mim.index', '', '');">
# <div class="item_wrp">
# <strong class="stock_item">유럽EUR</strong><span class="time">08.19 15:32</span>
# </div>
# <div class="price_wrp">
# <span class="stock_price">1,410.77</span>
# <div class="gap_wrp">
# <span class="gap_price"><em class="ico">상승</em>0.39</span><span class="gap_rate">+0.03<span class="per">%</span></span>
# </div>
# </div>
# </a>
# </li>
# <li class="stock_dn">
# <a href="/marketindex/item.nhn?marketindexCd=FX_JPYKRW&amp;menu=exchange" onclick="nclk(this, 'mim.index', '', '');">
# <div class="item_wrp">
# <strong class="stock_item">일본JPY</strong><span class="time">08.19 15:32</span>
# </div>
# <div class="price_wrp">
# <span class="stock_price">1,119.53</span>
# <div class="gap_wrp">
# <span class="gap_price"><em class="ico">하락</em>2.31</span><span class="gap_rate">-0.21<span class="per">%</span></span>
# </div>
# </div>
# </a>
# </li>
# <li class="stock_dn">
# <a href="/marketindex/item.nhn?marketindexCd=FX_CNYKRW&amp;menu=exchange" onclick="nclk(this, 'mim.index', '', '');">
# <div class="item_wrp">
# <strong class="stock_item">중국CNY</strong><span class="time">08.19 15:32</span>
# </div>
# <div class="price_wrp">
# <span class="stock_price">170.92</span>
# <div class="gap_wrp">
# <span class="gap_price"><em class="ico">하락</em>0.30</span><span class="gap_rate">-0.18<span class="per">%</span></span>
# </div>
# </div>
# </a>
# </li>
# <li class="stock_up">
# <a href="/marketindex/item.nhn?marketindexCd=CMDT_GC" onclick="nclk(this, 'mim.index', '', '');">
# <div class="item_wrp">
# <strong class="stock_item">국제금</strong><span class="time">08.18 </span>
# </div>
# <div class="price_wrp">
# <span class="stock_price">1,999.40</span>
# <div class="gap_wrp">
# <span class="gap_price"><em class="ico">상승</em>14.40</span><span class="gap_rate">+0.72<span class="per">%</span></span>
# </div>
# </div>
# </a>
# </li>
# <li class="null">
# <a href="/marketindex/item.nhn?marketindexCd=OIL_CL" onclick="nclk(this, 'mim.index', '', '');">
# <div class="item_wrp">
# <strong class="stock_item">유가WTI</strong><span class="time">08.18 </span>
# </div>
# <div class="price_wrp">
# <span class="stock_price">42.89</span>
# <div class="gap_wrp">
# <span class="gap_price"><em class="ico">보합</em>0.00</span><span class="gap_rate">0.00<span class="per">%</span></span>
# </div>
# </div>
# </a>
# </li>
# </ul>
# </div>
# <!-- [D]
# 			1.환율 선택시, exchag_on 클래스 추가(환율일 경우에만 환율계산,더보기 보이도록 css 처리해두었습니다.)
# 			2.유가·금 선택시, oil_on 클래스 추가
# 			3.그외에는 클래스 추가 없음
# 		-->
# <div class="ct_box mkindex exchg_on" id="menuTab">
# <h3 class="blind">환율,유가·금,금리,원자재</h3>
# <ul class="lnb_lst thin">
# <li class="on" id="exchange"><a href="/marketindex/index.nhn?menu=exchange#exchange" onclick="nclk(this, 'mim.xch', '', '');"><span class="txt">환율</span></a></li>
# <li id="oilgold"><a href="/marketindex/index.nhn?menu=oilgold#oilgold" onclick="nclk(this, 'mim.oilgold', '', '');"><span class="txt">유가·금</span></a></li>
# <li id="interest"><a href="/marketindex/index.nhn?menu=interest#interest" onclick="nclk(this, 'mim.itr', '', '');"><span class="txt">금리</span></a></li>
# <li id="material"><a href="/marketindex/index.nhn?menu=material#material" onclick="nclk(this, 'mim.mtr', '', '');"><span class="txt">원자재</span></a></li>
# </ul>
# <!-- 환율계산 -->
# <div class="exchange">
# <h4 class="blind">환율계산</h4>
# <div class="exchg_wrp">
# <div class="exchg_box">
# <div class="slc">
# <label class="blind" for="ecg_ifmt">환율을 계산할 국가를 선택</label>
# <select id="exchangeFrom" onchange="nclk(this, 'mil.xcal', '', '', 1)">
# <option data-unit="KRW" value="1">대한민국</option>
# <option data-unit="ZAR" value="68.33">남아프리카</option>
# <option data-unit="NOK" value="133.63">노르웨이</option>
# <option data-unit="NZD" value="782.09">뉴질랜드</option>
# <option data-unit="TWD" value="40.19">대만</option>
# <option data-unit="DKK" value="189.45">덴마크</option>
# <option data-unit="RUB" value="16.17">러시아</option>
# <option data-unit="MYR" value="282.59">말레이지아</option>
# <option data-unit="MXN" value="53.36">멕시코</option>
# <option data-unit="MNT" value="0.41">몽골</option>
# <option data-unit="USD" selected="true" value="1181.5">미국</option>
# <option data-unit="BHD" value="3134.12">바레인</option>
# <option data-unit="BDT" value="13.93">방글라데시</option>
# <option data-unit="VND" value="0.051">베트남</option>
# <option data-unit="BRL" value="216.1">브라질</option>
# <option data-unit="BND" value="865.85">브루나이</option>
# <option data-unit="SAR" value="315.02">사우디</option>
# <option data-unit="SEK" value="136.78">스웨덴</option>
# <option data-unit="CHF" value="1308.63">스위스</option>
# <option data-unit="SGD" value="865.85">싱가포르</option>
# <option data-unit="AED" value="321.66">아랍에미</option>
# <option data-unit="GBP" value="1566.02">영국</option>
# <option data-unit="OMR" value="3068.83">오만</option>
# <option data-unit="JOD" value="1666.43">요르단</option>
# <option data-unit="EUR" value="1410.77">유럽연합</option>
# <option data-unit="ILS" value="347.47">이스라엘</option>
# <option data-unit="EGP" value="74.21">이집트</option>
# <option data-unit="INR" value="15.79">인도</option>
# <option data-unit="IDR" value="0.0801">인도네시아</option>
# <option data-unit="JPY" value="11.1953">일본</option>
# <option data-unit="CNY" value="170.92">중국원화</option>
# <option data-unit="CZK" value="54.05">체코</option>
# <option data-unit="CLP" value="1.49">칠레</option>
# <option data-unit="KZT" value="2.82">카자흐스탄</option>
# <option data-unit="QAR" value="322.04">카타르</option>
# <option data-unit="CAD" value="898.04">캐나다</option>
# <option data-unit="KWD" value="3869.33">쿠웨이트</option>
# <option data-unit="THB" value="37.89">태국</option>
# <option data-unit="TRY" value="160.12">터키</option>
# <option data-unit="PKR" value="7.01">파키스탄</option>
# <option data-unit="PLN" value="322.44">폴란드</option>
# <option data-unit="PHP" value="24.35">필리핀</option>
# <option data-unit="HUF" value="4.05">헝가리</option>
# <option data-unit="AUD" value="856.59">호주</option>
# <option data-unit="HKD" value="152.45">홍콩</option>
# </select>
# <span class="eng">USD</span>
# </div>
# <div class="amount">
# <label class="blind" for="amount_n">금액 입력</label>
# <input id="amount_n" maxlength="17" min="0" type="tel" value="0"/>
# <span class="nb_txt" id="exchangeFromSign"><span class="num" id="exchangeValue">0 </span></span>
# </div>
# </div>
# </div>
# <span class="eq">전환</span>
# <div class="exchg_wrp">
# <div class="exchg_box">
# <div class="slc">
# <label class="blind" for="ecg_ifmt">환율을 변환할 국가를 선택</label>
# <select id="exchangeTo" onchange="nclk(this, 'mil.xcal', '', '', 1)">
# <option data-unit="KRW" selected="true" value="1">대한민국</option>
# <option data-unit="ZAR" value="68.33">남아프리카</option>
# <option data-unit="NOK" value="133.63">노르웨이</option>
# <option data-unit="NZD" value="782.09">뉴질랜드</option>
# <option data-unit="TWD" value="40.19">대만</option>
# <option data-unit="DKK" value="189.45">덴마크</option>
# <option data-unit="RUB" value="16.17">러시아</option>
# <option data-unit="MYR" value="282.59">말레이지아</option>
# <option data-unit="MXN" value="53.36">멕시코</option>
# <option data-unit="MNT" value="0.41">몽골</option>
# <option data-unit="USD" value="1181.5">미국</option>
# <option data-unit="BHD" value="3134.12">바레인</option>
# <option data-unit="BDT" value="13.93">방글라데시</option>
# <option data-unit="VND" value="0.051">베트남</option>
# <option data-unit="BRL" value="216.1">브라질</option>
# <option data-unit="BND" value="865.85">브루나이</option>
# <option data-unit="SAR" value="315.02">사우디</option>
# <option data-unit="SEK" value="136.78">스웨덴</option>
# <option data-unit="CHF" value="1308.63">스위스</option>
# <option data-unit="SGD" value="865.85">싱가포르</option>
# <option data-unit="AED" value="321.66">아랍에미</option>
# <option data-unit="GBP" value="1566.02">영국</option>
# <option data-unit="OMR" value="3068.83">오만</option>
# <option data-unit="JOD" value="1666.43">요르단</option>
# <option data-unit="EUR" value="1410.77">유럽연합</option>
# <option data-unit="ILS" value="347.47">이스라엘</option>
# <option data-unit="EGP" value="74.21">이집트</option>
# <option data-unit="INR" value="15.79">인도</option>
# <option data-unit="IDR" value="0.0801">인도네시아</option>
# <option data-unit="JPY" value="11.1953">일본</option>
# <option data-unit="CNY" value="170.92">중국원화</option>
# <option data-unit="CZK" value="54.05">체코</option>
# <option data-unit="CLP" value="1.49">칠레</option>
# <option data-unit="KZT" value="2.82">카자흐스탄</option>
# <option data-unit="QAR" value="322.04">카타르</option>
# <option data-unit="CAD" value="898.04">캐나다</option>
# <option data-unit="KWD" value="3869.33">쿠웨이트</option>
# <option data-unit="THB" value="37.89">태국</option>
# <option data-unit="TRY" value="160.12">터키</option>
# <option data-unit="PKR" value="7.01">파키스탄</option>
# <option data-unit="PLN" value="322.44">폴란드</option>
# <option data-unit="PHP" value="24.35">필리핀</option>
# <option data-unit="HUF" value="4.05">헝가리</option>
# <option data-unit="AUD" value="856.59">호주</option>
# <option data-unit="HKD" value="152.45">홍콩</option>
# </select>
# <span class="eng">KRW</span>
# </div>
# <div class="amount">
# <label class="blind" for="amount_n2">금액 입력</label>
# <input id="amount_n2" min="0" type="tel" value="0"/>
# <span class="nb_txt" id="exchangeResultSign"><span class="num" id="exchangeResult">0.00 </span></span>
# </div>
# </div>
# </div>
# </div>
# <script type="text/javascript">
#             function initExchange(){
#
#                     var htCurrency = {
#                         'KRW': '원',
#                         'USD': '달러',
#                         'EUR': '유로',
#                         'JPY': '엔',
#                         'CNY': '위안',
#                         'HKD': '달러',
#                         'TWD': '달러',
#                         'GBP': '파운드',
#                         'CAD': '달러',
#                         'CHF': '프랑',
#                         'SEK': '크로나',
#                         'AUD': '달러',
#                         'NZD': '달러',
#                         'CZK': '코루나',
#                         'TRY': '리라',
#                         'MNT': '투그릭',
#                         'ILS': '세켈',
#                         'DKK': '크로네',
#                         'NOK': '크로네',
#                         'SAR': '리얄',
#                         'KWD': '디나르',
#                         'BHD': '디나르',
#                         'AED': '디르함',
#                         'JOD': '디나르',
#                         'EGP': '파운드',
#                         'THB': '바트',
#                         'SGD': '달러',
#                         'MYR': '링깃',
#                         'IDR': '루피아',
#                         'QAR': '리얄',
#                         'KZT': '텡게',
#                         'BND': '달러',
#                         'INR': '루피',
#                         'PKR': '루피',
#                         'BDT': '타카',
#                         'PHP': '페소',
#                         'MXN': '페소',
#                         'BRL': '레알',
#                         'VND': '동',
#                         'ZAR': '랜드',
#                         'RUB': '루블',
#                         'HUF': '포린트',
#                         'PLN': '즈워티',
#                         'OMR': '리알',
#                         'CLP': '페소'
#                     };
#
#                     var oExchange = new nhn.mobile.stock.Exchange(jindo.$$.getSingle("div.exchange"), htCurrency);
#
#         	}
#             </script>
# <!-- // 환율계산 -->
# <div class="lst_wrp">
# <h4 class="blind">환율</h4>
# <ul class="item_lst" id="marketindexLastList">
# <!-- [D]
# 						1. 달러인덱스 : index 클래스 추가
# 						2. 그외 국가별 클래스는 위 span.eng 텍스트(소문자)와 동일하게 붙여주세요. (ex.대한민국 = krw / 미국 = usd)
# 					-->
# <li class="stock_dn index">
# <a href="/marketindex/item.nhn?marketindexCd=FX_USDX" onclick="nclk(this, 'mil.xch', '', '');">
# <div class="item_wrp">
# <span class="stock_item">달러인덱스</span>
# <span class="time">08.18 </span>
# </div>
# <div class="price_wrp">
# <span class="stock_price">92.25</span>
# <div class="gap_wrp">
# <span class="gap_price"><span class="ico">하락</span>0.59</span><span class="gap_rate">-0.64<span class="per">%</span></span>
# </div>
# </div>
# </a>
# </li>
# <li class="stock_up zar">
# <a href="/marketindex/item.nhn?marketindexCd=FX_ZARKRW&amp;menu=exchange" onclick="nclk(this,'mil.xch', '', '');">
# <div class="item_wrp">
# <span class="stock_item">남아프리카 ZAR</span>
# <span class="time">08.19 15:32</span>
# </div>
# <div class="price_wrp">
# <span class="stock_price">68.33</span>
# <div class="gap_wrp">
# <span class="gap_price"><span class="ico">상승</span>0.23</span><span class="gap_rate">+0.34<span class="per">%</span></span>
# </div>
# </div>
# <span class="eng"></span>
# </a>
# </li>
# <li class="stock_dn nok">
# <a href="/marketindex/item.nhn?marketindexCd=FX_NOKKRW&amp;menu=exchange" onclick="nclk(this,'mil.xch', '', '');">
# <div class="item_wrp">
# <span class="stock_item">노르웨이 NOK</span>
# <span class="time">08.19 15:32</span>
# </div>
# <div class="price_wrp">
# <span class="stock_price">133.63</span>
# <div class="gap_wrp">
# <span class="gap_price"><span class="ico">하락</span>0.59</span><span class="gap_rate">-0.44<span class="per">%</span></span>
# </div>
# </div>
# <span class="eng"></span>
# </a>
# </li>
# <li class="stock_up nzd">
# <a href="/marketindex/item.nhn?marketindexCd=FX_NZDKRW&amp;menu=exchange" onclick="nclk(this,'mil.xch', '', '');">
# <div class="item_wrp">
# <span class="stock_item">뉴질랜드 NZD</span>
# <span class="time">08.19 15:32</span>
# </div>
# <div class="price_wrp">
# <span class="stock_price">782.09</span>
# <div class="gap_wrp">
# <span class="gap_price"><span class="ico">상승</span>4.70</span><span class="gap_rate">+0.60<span class="per">%</span></span>
# </div>
# </div>
# <span class="eng"></span>
# </a>
# </li>
# <li class="stock_dn twd">
# <a href="/marketindex/item.nhn?marketindexCd=FX_TWDKRW&amp;menu=exchange" onclick="nclk(this,'mil.xch', '', '');">
# <div class="item_wrp">
# <span class="stock_item">대만 TWD</span>
# <span class="time">08.19 15:32</span>
# </div>
# <div class="price_wrp">
# <span class="stock_price">40.19</span>
# <div class="gap_wrp">
# <span class="gap_price"><span class="ico">하락</span>0.12</span><span class="gap_rate">-0.30<span class="per">%</span></span>
# </div>
# </div>
# <span class="eng"></span>
# </a>
# </li>
# <li class="stock_up dkk">
# <a href="/marketindex/item.nhn?marketindexCd=FX_DKKKRW&amp;menu=exchange" onclick="nclk(this,'mil.xch', '', '');">
# <div class="item_wrp">
# <span class="stock_item">덴마크 DKK</span>
# <span class="time">08.19 15:32</span>
# </div>
# <div class="price_wrp">
# <span class="stock_price">189.45</span>
# <div class="gap_wrp">
# <span class="gap_price"><span class="ico">상승</span>0.04</span><span class="gap_rate">+0.02<span class="per">%</span></span>
# </div>
# </div>
# <span class="eng"></span>
# </a>
# </li>
# <li class="stock_dn rub">
# <a href="/marketindex/item.nhn?marketindexCd=FX_RUBKRW&amp;menu=exchange" onclick="nclk(this,'mil.xch', '', '');">
# <div class="item_wrp">
# <span class="stock_item">러시아 RUB</span>
# <span class="time">08.19 15:32</span>
# </div>
# <div class="price_wrp">
# <span class="stock_price">16.17</span>
# <div class="gap_wrp">
# <span class="gap_price"><span class="ico">하락</span>0.05</span><span class="gap_rate">-0.31<span class="per">%</span></span>
# </div>
# </div>
# <span class="eng"></span>
# </a>
# </li>
# <li class="stock_dn myr">
# <a href="/marketindex/item.nhn?marketindexCd=FX_MYRKRW&amp;menu=exchange" onclick="nclk(this,'mil.xch', '', '');">
# <div class="item_wrp">
# <span class="stock_item">말레이지아 MYR</span>
# <span class="time">08.19 15:32</span>
# </div>
# <div class="price_wrp">
# <span class="stock_price">282.59</span>
# <div class="gap_wrp">
# <span class="gap_price"><span class="ico">하락</span>0.61</span><span class="gap_rate">-0.22<span class="per">%</span></span>
# </div>
# </div>
# <span class="eng"></span>
# </a>
# </li>
# <li class="stock_dn mxn">
# <a href="/marketindex/item.nhn?marketindexCd=FX_MXNKRW&amp;menu=exchange" onclick="nclk(this,'mil.xch', '', '');">
# <div class="item_wrp">
# <span class="stock_item">멕시코 MXN</span>
# <span class="time">08.19 15:32</span>
# </div>
# <div class="price_wrp">
# <span class="stock_price">53.36</span>
# <div class="gap_wrp">
# <span class="gap_price"><span class="ico">하락</span>0.41</span><span class="gap_rate">-0.76<span class="per">%</span></span>
# </div>
# </div>
# <span class="eng"></span>
# </a>
# </li>
# <li class="null mnt">
# <a href="/marketindex/item.nhn?marketindexCd=FX_MNTKRW&amp;menu=exchange" onclick="nclk(this,'mil.xch', '', '');">
# <div class="item_wrp">
# <span class="stock_item">몽골 MNT</span>
# <span class="time">08.19 15:32</span>
# </div>
# <div class="price_wrp">
# <span class="stock_price">0.41</span>
# <div class="gap_wrp">
# <span class="gap_price"><span class="ico">보합</span>0.00</span><span class="gap_rate">0.00<span class="per">%</span></span>
# </div>
# </div>
# <span class="eng"></span>
# </a>
# </li>
# <li class="stock_dn usd">
# <a href="/marketindex/item.nhn?marketindexCd=FX_USDKRW&amp;menu=exchange" onclick="nclk(this,'mil.xch', '', '');">
# <div class="item_wrp">
# <span class="stock_item">미국 USD</span>
# <span class="time">08.19 15:32</span>
# </div>
# <div class="price_wrp">
# <span class="stock_price">1,181.50</span>
# <div class="gap_wrp">
# <span class="gap_price"><span class="ico">하락</span>3.00</span><span class="gap_rate">-0.25<span class="per">%</span></span>
# </div>
# </div>
# <span class="eng"></span>
# </a>
# </li>
# <li class="stock_dn bhd">
# <a href="/marketindex/item.nhn?marketindexCd=FX_BHDKRW&amp;menu=exchange" onclick="nclk(this,'mil.xch', '', '');">
# <div class="item_wrp">
# <span class="stock_item">바레인 BHD</span>
# <span class="time">08.19 15:32</span>
# </div>
# <div class="price_wrp">
# <span class="stock_price">3,134.12</span>
# <div class="gap_wrp">
# <span class="gap_price"><span class="ico">하락</span>7.96</span><span class="gap_rate">-0.25<span class="per">%</span></span>
# </div>
# </div>
# <span class="eng"></span>
# </a>
# </li>
# <li class="stock_dn bdt">
# <a href="/marketindex/item.nhn?marketindexCd=FX_BDTKRW&amp;menu=exchange" onclick="nclk(this,'mil.xch', '', '');">
# <div class="item_wrp">
# <span class="stock_item">방글라데시 BDT</span>
# <span class="time">08.19 15:32</span>
# </div>
# <div class="price_wrp">
# <span class="stock_price">13.93</span>
# <div class="gap_wrp">
# <span class="gap_price"><span class="ico">하락</span>0.04</span><span class="gap_rate">-0.29<span class="per">%</span></span>
# </div>
# </div>
# <span class="eng"></span>
# </a>
# </li>
# <li class="stock_dn vnd">
# <a href="/marketindex/item.nhn?marketindexCd=FX_VNDKRW&amp;menu=exchange" onclick="nclk(this,'mil.xch', '', '');">
# <div class="item_wrp">
# <span class="stock_item">베트남 VND 100</span>
# <span class="time">08.19 15:32</span>
# </div>
# <div class="price_wrp">
# <span class="stock_price">5.10</span>
# <div class="gap_wrp">
# <span class="gap_price"><span class="ico">하락</span>0.01</span><span class="gap_rate">-0.20<span class="per">%</span></span>
# </div>
# </div>
# <span class="eng"></span>
# </a>
# </li>
# <li class="stock_up brl">
# <a href="/marketindex/item.nhn?marketindexCd=FX_BRLKRW&amp;menu=exchange" onclick="nclk(this,'mil.xch', '', '');">
# <div class="item_wrp">
# <span class="stock_item">브라질 BRL</span>
# <span class="time">08.19 15:32</span>
# </div>
# <div class="price_wrp">
# <span class="stock_price">216.10</span>
# <div class="gap_wrp">
# <span class="gap_price"><span class="ico">상승</span>1.11</span><span class="gap_rate">+0.52<span class="per">%</span></span>
# </div>
# </div>
# <span class="eng"></span>
# </a>
# </li>
# <li class="stock_dn bnd">
# <a href="/marketindex/item.nhn?marketindexCd=FX_BNDKRW&amp;menu=exchange" onclick="nclk(this,'mil.xch', '', '');">
# <div class="item_wrp">
# <span class="stock_item">브루나이 BND</span>
# <span class="time">08.19 15:32</span>
# </div>
# <div class="price_wrp">
# <span class="stock_price">865.85</span>
# <div class="gap_wrp">
# <span class="gap_price"><span class="ico">하락</span>2.07</span><span class="gap_rate">-0.24<span class="per">%</span></span>
# </div>
# </div>
# <span class="eng"></span>
# </a>
# </li>
# <li class="stock_dn sar">
# <a href="/marketindex/item.nhn?marketindexCd=FX_SARKRW&amp;menu=exchange" onclick="nclk(this,'mil.xch', '', '');">
# <div class="item_wrp">
# <span class="stock_item">사우디 SAR</span>
# <span class="time">08.19 15:32</span>
# </div>
# <div class="price_wrp">
# <span class="stock_price">315.02</span>
# <div class="gap_wrp">
# <span class="gap_price"><span class="ico">하락</span>0.81</span><span class="gap_rate">-0.26<span class="per">%</span></span>
# </div>
# </div>
# <span class="eng"></span>
# </a>
# </li>
# <li class="stock_up sek">
# <a href="/marketindex/item.nhn?marketindexCd=FX_SEKKRW&amp;menu=exchange" onclick="nclk(this,'mil.xch', '', '');">
# <div class="item_wrp">
# <span class="stock_item">스웨덴 SEK</span>
# <span class="time">08.19 15:32</span>
# </div>
# <div class="price_wrp">
# <span class="stock_price">136.78</span>
# <div class="gap_wrp">
# <span class="gap_price"><span class="ico">상승</span>0.21</span><span class="gap_rate">+0.15<span class="per">%</span></span>
# </div>
# </div>
# <span class="eng"></span>
# </a>
# </li>
# <li class="stock_up chf">
# <a href="/marketindex/item.nhn?marketindexCd=FX_CHFKRW&amp;menu=exchange" onclick="nclk(this,'mil.xch', '', '');">
# <div class="item_wrp">
# <span class="stock_item">스위스 CHF</span>
# <span class="time">08.19 15:32</span>
# </div>
# <div class="price_wrp">
# <span class="stock_price">1,308.63</span>
# <div class="gap_wrp">
# <span class="gap_price"><span class="ico">상승</span>0.22</span><span class="gap_rate">+0.02<span class="per">%</span></span>
# </div>
# </div>
# <span class="eng"></span>
# </a>
# </li>
# <li class="stock_dn sgd">
# <a href="/marketindex/item.nhn?marketindexCd=FX_SGDKRW&amp;menu=exchange" onclick="nclk(this,'mil.xch', '', '');">
# <div class="item_wrp">
# <span class="stock_item">싱가포르 SGD</span>
# <span class="time">08.19 15:32</span>
# </div>
# <div class="price_wrp">
# <span class="stock_price">865.85</span>
# <div class="gap_wrp">
# <span class="gap_price"><span class="ico">하락</span>2.07</span><span class="gap_rate">-0.24<span class="per">%</span></span>
# </div>
# </div>
# <span class="eng"></span>
# </a>
# </li>
# <li class="stock_dn aed">
# <a href="/marketindex/item.nhn?marketindexCd=FX_AEDKRW&amp;menu=exchange" onclick="nclk(this,'mil.xch', '', '');">
# <div class="item_wrp">
# <span class="stock_item">아랍에미 AED</span>
# <span class="time">08.19 15:32</span>
# </div>
# <div class="price_wrp">
# <span class="stock_price">321.66</span>
# <div class="gap_wrp">
# <span class="gap_price"><span class="ico">하락</span>0.82</span><span class="gap_rate">-0.25<span class="per">%</span></span>
# </div>
# </div>
# <span class="eng"></span>
# </a>
# </li>
# <li class="stock_up gbp">
# <a href="/marketindex/item.nhn?marketindexCd=FX_GBPKRW&amp;menu=exchange" onclick="nclk(this,'mil.xch', '', '');">
# <div class="item_wrp">
# <span class="stock_item">영국 GBP</span>
# <span class="time">08.19 15:32</span>
# </div>
# <div class="price_wrp">
# <span class="stock_price">1,566.02</span>
# <div class="gap_wrp">
# <span class="gap_price"><span class="ico">상승</span>5.09</span><span class="gap_rate">+0.33<span class="per">%</span></span>
# </div>
# </div>
# <span class="eng"></span>
# </a>
# </li>
# <li class="stock_dn omr">
# <a href="/marketindex/item.nhn?marketindexCd=FX_OMRKRW&amp;menu=exchange" onclick="nclk(this,'mil.xch', '', '');">
# <div class="item_wrp">
# <span class="stock_item">오만 OMR</span>
# <span class="time">08.19 15:32</span>
# </div>
# <div class="price_wrp">
# <span class="stock_price">3,068.83</span>
# <div class="gap_wrp">
# <span class="gap_price"><span class="ico">하락</span>7.63</span><span class="gap_rate">-0.25<span class="per">%</span></span>
# </div>
# </div>
# <span class="eng"></span>
# </a>
# </li>
# <li class="stock_dn jod">
# <a href="/marketindex/item.nhn?marketindexCd=FX_JODKRW&amp;menu=exchange" onclick="nclk(this,'mil.xch', '', '');">
# <div class="item_wrp">
# <span class="stock_item">요르단 JOD</span>
# <span class="time">08.19 15:32</span>
# </div>
# <div class="price_wrp">
# <span class="stock_price">1,666.43</span>
# <div class="gap_wrp">
# <span class="gap_price"><span class="ico">하락</span>4.23</span><span class="gap_rate">-0.25<span class="per">%</span></span>
# </div>
# </div>
# <span class="eng"></span>
# </a>
# </li>
# <li class="stock_up eur">
# <a href="/marketindex/item.nhn?marketindexCd=FX_EURKRW&amp;menu=exchange" onclick="nclk(this,'mil.xch', '', '');">
# <div class="item_wrp">
# <span class="stock_item">유럽연합 EUR</span>
# <span class="time">08.19 15:32</span>
# </div>
# <div class="price_wrp">
# <span class="stock_price">1,410.77</span>
# <div class="gap_wrp">
# <span class="gap_price"><span class="ico">상승</span>0.39</span><span class="gap_rate">+0.03<span class="per">%</span></span>
# </div>
# </div>
# <span class="eng"></span>
# </a>
# </li>
# <li class="stock_dn ils">
# <a href="/marketindex/item.nhn?marketindexCd=FX_ILSKRW&amp;menu=exchange" onclick="nclk(this,'mil.xch', '', '');">
# <div class="item_wrp">
# <span class="stock_item">이스라엘 ILS</span>
# <span class="time">08.19 15:32</span>
# </div>
# <div class="price_wrp">
# <span class="stock_price">347.47</span>
# <div class="gap_wrp">
# <span class="gap_price"><span class="ico">하락</span>0.82</span><span class="gap_rate">-0.24<span class="per">%</span></span>
# </div>
# </div>
# <span class="eng"></span>
# </a>
# </li>
# <li class="stock_dn egp">
# <a href="/marketindex/item.nhn?marketindexCd=FX_EGPKRW&amp;menu=exchange" onclick="nclk(this,'mil.xch', '', '');">
# <div class="item_wrp">
# <span class="stock_item">이집트 EGP</span>
# <span class="time">08.19 15:32</span>
# </div>
# <div class="price_wrp">
# <span class="stock_price">74.21</span>
# <div class="gap_wrp">
# <span class="gap_price"><span class="ico">하락</span>0.09</span><span class="gap_rate">-0.12<span class="per">%</span></span>
# </div>
# </div>
# <span class="eng"></span>
# </a>
# </li>
# <li class="stock_dn inr">
# <a href="/marketindex/item.nhn?marketindexCd=FX_INRKRW&amp;menu=exchange" onclick="nclk(this,'mil.xch', '', '');">
# <div class="item_wrp">
# <span class="stock_item">인도 INR</span>
# <span class="time">08.19 15:32</span>
# </div>
# <div class="price_wrp">
# <span class="stock_price">15.79</span>
# <div class="gap_wrp">
# <span class="gap_price"><span class="ico">하락</span>0.08</span><span class="gap_rate">-0.50<span class="per">%</span></span>
# </div>
# </div>
# <span class="eng"></span>
# </a>
# </li>
# <li class="stock_up idr">
# <a href="/marketindex/item.nhn?marketindexCd=FX_IDRKRW&amp;menu=exchange" onclick="nclk(this,'mil.xch', '', '');">
# <div class="item_wrp">
# <span class="stock_item">인도네시아 IDR</span>
# <span class="time">08.19 15:32</span>
# </div>
# <div class="price_wrp">
# <span class="stock_price">8.01</span>
# <div class="gap_wrp">
# <span class="gap_price"><span class="ico">상승</span>0.01</span><span class="gap_rate">+0.12<span class="per">%</span></span>
# </div>
# </div>
# <span class="eng"></span>
# </a>
# </li>
# <li class="stock_dn jpy">
# <a href="/marketindex/item.nhn?marketindexCd=FX_JPYKRW&amp;menu=exchange" onclick="nclk(this,'mil.xch', '', '');">
# <div class="item_wrp">
# <span class="stock_item">일본 JPY 100</span>
# <span class="time">08.19 15:32</span>
# </div>
# <div class="price_wrp">
# <span class="stock_price">1,119.53</span>
# <div class="gap_wrp">
# <span class="gap_price"><span class="ico">하락</span>2.31</span><span class="gap_rate">-0.21<span class="per">%</span></span>
# </div>
# </div>
# <span class="eng"></span>
# </a>
# </li>
# <li class="stock_dn cny">
# <a href="/marketindex/item.nhn?marketindexCd=FX_CNYKRW&amp;menu=exchange" onclick="nclk(this,'mil.xch', '', '');">
# <div class="item_wrp">
# <span class="stock_item">중국원화 CNY</span>
# <span class="time">08.19 15:32</span>
# </div>
# <div class="price_wrp">
# <span class="stock_price">170.92</span>
# <div class="gap_wrp">
# <span class="gap_price"><span class="ico">하락</span>0.30</span><span class="gap_rate">-0.18<span class="per">%</span></span>
# </div>
# </div>
# <span class="eng"></span>
# </a>
# </li>
# <li class="stock_up czk">
# <a href="/marketindex/item.nhn?marketindexCd=FX_CZKKRW&amp;menu=exchange" onclick="nclk(this,'mil.xch', '', '');">
# <div class="item_wrp">
# <span class="stock_item">체코 CZK</span>
# <span class="time">08.19 15:32</span>
# </div>
# <div class="price_wrp">
# <span class="stock_price">54.05</span>
# <div class="gap_wrp">
# <span class="gap_price"><span class="ico">상승</span>0.08</span><span class="gap_rate">+0.15<span class="per">%</span></span>
# </div>
# </div>
# <span class="eng"></span>
# </a>
# </li>
# <li class="stock_up clp">
# <a href="/marketindex/item.nhn?marketindexCd=FX_CLPKRW&amp;menu=exchange" onclick="nclk(this,'mil.xch', '', '');">
# <div class="item_wrp">
# <span class="stock_item">칠레 CLP</span>
# <span class="time">08.19 15:32</span>
# </div>
# <div class="price_wrp">
# <span class="stock_price">1.49</span>
# <div class="gap_wrp">
# <span class="gap_price"><span class="ico">상승</span>0.02</span><span class="gap_rate">+1.36<span class="per">%</span></span>
# </div>
# </div>
# <span class="eng"></span>
# </a>
# </li>
# <li class="stock_dn kzt">
# <a href="/marketindex/item.nhn?marketindexCd=FX_KZTKRW&amp;menu=exchange" onclick="nclk(this,'mil.xch', '', '');">
# <div class="item_wrp">
# <span class="stock_item">카자흐스탄 KZT</span>
# <span class="time">08.19 15:32</span>
# </div>
# <div class="price_wrp">
# <span class="stock_price">2.82</span>
# <div class="gap_wrp">
# <span class="gap_price"><span class="ico">하락</span>0.01</span><span class="gap_rate">-0.35<span class="per">%</span></span>
# </div>
# </div>
# <span class="eng"></span>
# </a>
# </li>
# <li class="stock_dn qar">
# <a href="/marketindex/item.nhn?marketindexCd=FX_QARKRW&amp;menu=exchange" onclick="nclk(this,'mil.xch', '', '');">
# <div class="item_wrp">
# <span class="stock_item">카타르 QAR</span>
# <span class="time">08.19 15:32</span>
# </div>
# <div class="price_wrp">
# <span class="stock_price">322.04</span>
# <div class="gap_wrp">
# <span class="gap_price"><span class="ico">하락</span>3.28</span><span class="gap_rate">-1.01<span class="per">%</span></span>
# </div>
# </div>
# <span class="eng"></span>
# </a>
# </li>
# <li class="stock_dn cad">
# <a href="/marketindex/item.nhn?marketindexCd=FX_CADKRW&amp;menu=exchange" onclick="nclk(this,'mil.xch', '', '');">
# <div class="item_wrp">
# <span class="stock_item">캐나다 CAD</span>
# <span class="time">08.19 15:32</span>
# </div>
# <div class="price_wrp">
# <span class="stock_price">898.04</span>
# <div class="gap_wrp">
# <span class="gap_price"><span class="ico">하락</span>1.76</span><span class="gap_rate">-0.20<span class="per">%</span></span>
# </div>
# </div>
# <span class="eng"></span>
# </a>
# </li>
# <li class="stock_dn kwd">
# <a href="/marketindex/item.nhn?marketindexCd=FX_KWDKRW&amp;menu=exchange" onclick="nclk(this,'mil.xch', '', '');">
# <div class="item_wrp">
# <span class="stock_item">쿠웨이트 KWD</span>
# <span class="time">08.19 15:32</span>
# </div>
# <div class="price_wrp">
# <span class="stock_price">3,869.33</span>
# <div class="gap_wrp">
# <span class="gap_price"><span class="ico">하락</span>7.92</span><span class="gap_rate">-0.20<span class="per">%</span></span>
# </div>
# </div>
# <span class="eng"></span>
# </a>
# </li>
# <li class="stock_dn thb">
# <a href="/marketindex/item.nhn?marketindexCd=FX_THBKRW&amp;menu=exchange" onclick="nclk(this,'mil.xch', '', '');">
# <div class="item_wrp">
# <span class="stock_item">태국 THB</span>
# <span class="time">08.19 15:32</span>
# </div>
# <div class="price_wrp">
# <span class="stock_price">37.89</span>
# <div class="gap_wrp">
# <span class="gap_price"><span class="ico">하락</span>0.17</span><span class="gap_rate">-0.45<span class="per">%</span></span>
# </div>
# </div>
# <span class="eng"></span>
# </a>
# </li>
# <li class="stock_dn try">
# <a href="/marketindex/item.nhn?marketindexCd=FX_TRYKRW&amp;menu=exchange" onclick="nclk(this,'mil.xch', '', '');">
# <div class="item_wrp">
# <span class="stock_item">터키 TRY</span>
# <span class="time">08.19 15:32</span>
# </div>
# <div class="price_wrp">
# <span class="stock_price">160.12</span>
# <div class="gap_wrp">
# <span class="gap_price"><span class="ico">하락</span>0.40</span><span class="gap_rate">-0.25<span class="per">%</span></span>
# </div>
# </div>
# <span class="eng"></span>
# </a>
# </li>
# <li class="stock_dn pkr">
# <a href="/marketindex/item.nhn?marketindexCd=FX_PKRKRW&amp;menu=exchange" onclick="nclk(this,'mil.xch', '', '');">
# <div class="item_wrp">
# <span class="stock_item">파키스탄 PKR</span>
# <span class="time">08.19 15:32</span>
# </div>
# <div class="price_wrp">
# <span class="stock_price">7.01</span>
# <div class="gap_wrp">
# <span class="gap_price"><span class="ico">하락</span>0.02</span><span class="gap_rate">-0.28<span class="per">%</span></span>
# </div>
# </div>
# <span class="eng"></span>
# </a>
# </li>
# <li class="stock_up pln">
# <a href="/marketindex/item.nhn?marketindexCd=FX_PLNKRW&amp;menu=exchange" onclick="nclk(this,'mil.xch', '', '');">
# <div class="item_wrp">
# <span class="stock_item">폴란드 PLN</span>
# <span class="time">08.19 15:32</span>
# </div>
# <div class="price_wrp">
# <span class="stock_price">322.44</span>
# <div class="gap_wrp">
# <span class="gap_price"><span class="ico">상승</span>1.16</span><span class="gap_rate">+0.36<span class="per">%</span></span>
# </div>
# </div>
# <span class="eng"></span>
# </a>
# </li>
# <li class="stock_dn php">
# <a href="/marketindex/item.nhn?marketindexCd=FX_PHPKRW&amp;menu=exchange" onclick="nclk(this,'mil.xch', '', '');">
# <div class="item_wrp">
# <span class="stock_item">필리핀 PHP</span>
# <span class="time">08.19 15:32</span>
# </div>
# <div class="price_wrp">
# <span class="stock_price">24.35</span>
# <div class="gap_wrp">
# <span class="gap_price"><span class="ico">하락</span>0.06</span><span class="gap_rate">-0.25<span class="per">%</span></span>
# </div>
# </div>
# <span class="eng"></span>
# </a>
# </li>
# <li class="stock_up huf">
# <a href="/marketindex/item.nhn?marketindexCd=FX_HUFKRW&amp;menu=exchange" onclick="nclk(this,'mil.xch', '', '');">
# <div class="item_wrp">
# <span class="stock_item">헝가리 HUF</span>
# <span class="time">08.19 15:32</span>
# </div>
# <div class="price_wrp">
# <span class="stock_price">4.05</span>
# <div class="gap_wrp">
# <span class="gap_price"><span class="ico">상승</span>0.02</span><span class="gap_rate">+0.50<span class="per">%</span></span>
# </div>
# </div>
# <span class="eng"></span>
# </a>
# </li>
# <li class="stock_dn aud">
# <a href="/marketindex/item.nhn?marketindexCd=FX_AUDKRW&amp;menu=exchange" onclick="nclk(this,'mil.xch', '', '');">
# <div class="item_wrp">
# <span class="stock_item">호주 AUD</span>
# <span class="time">08.19 15:32</span>
# </div>
# <div class="price_wrp">
# <span class="stock_price">856.59</span>
# <div class="gap_wrp">
# <span class="gap_price"><span class="ico">하락</span>0.28</span><span class="gap_rate">-0.03<span class="per">%</span></span>
# </div>
# </div>
# <span class="eng"></span>
# </a>
# </li>
# <li class="stock_dn hkd">
# <a href="/marketindex/item.nhn?marketindexCd=FX_HKDKRW&amp;menu=exchange" onclick="nclk(this,'mil.xch', '', '');">
# <div class="item_wrp">
# <span class="stock_item">홍콩 HKD</span>
# <span class="time">08.19 15:32</span>
# </div>
# <div class="price_wrp">
# <span class="stock_price">152.45</span>
# <div class="gap_wrp">
# <span class="gap_price"><span class="ico">하락</span>0.38</span><span class="gap_rate">-0.25<span class="per">%</span></span>
# </div>
# </div>
# <span class="eng"></span>
# </a>
# </li>
# <li class="spare"></li>
# <!-- li 반복 -->
# </ul>
# </div>
# </div>
# </div>
# </div>
# <!-- //content -->
# </body>

# %%
from bs4 import BeautifulSoup
import requests

#URL 가져오기
url = 'https://m.stock.naver.com/marketindex/index.nhn'
response = requests.get(url)

#Soup 객체 생성
soup = BeautifulSoup(response.text, 'html.parser')

#원하는 데이터 추출 - 국가
country = []
country_1 = soup.findAll('strong')
country_2 = soup.findAll('span', {'class':'stock_item'})
for c in country_1:
    country.append(c.text)
for c in country_2:
    country.append(c.text)
country.remove('컨텐츠 제공업체')
country.remove('증권')

#원하는 데이터 추출 - 환율정보
price = []
price_0 = soup.findAll('span', {"class":"stock_price"})
for p in price_0:
    price.append(p.text)

#데이터 정렬, (pandas)
import pandas as pd
data = {}
for i in range(len(country)):
    data[country[i]] = price[i]
    
pd.Series(data)
# Out:
# 미국USD          1,181.50
# 유럽EUR          1,410.77
# 일본JPY          1,119.53
# 중국CNY            170.92
# 국제금            1,999.40
# 유가WTI             42.89
# 달러인덱스             92.25
# 남아프리카 ZAR         68.33
# 노르웨이 NOK         133.63
# 뉴질랜드 NZD         782.09
# 대만 TWD            40.19
# 덴마크 DKK          189.45
# 러시아 RUB           16.17
# 말레이지아 MYR        282.59
# 멕시코 MXN           53.36
# 몽골 MNT             0.41
# 미국 USD         1,181.50
# 바레인 BHD        3,134.12
# 방글라데시 BDT         13.93
# 베트남 VND 100        5.10
# 브라질 BRL          216.10
# 브루나이 BND         865.85
# 사우디 SAR          315.02
# 스웨덴 SEK          136.78
# 스위스 CHF        1,308.63
# 싱가포르 SGD         865.85
# 아랍에미 AED         321.66
# 영국 GBP         1,566.02
# 오만 OMR         3,068.83
# 요르단 JOD        1,666.43
# 유럽연합 EUR       1,410.77
# 이스라엘 ILS         347.47
# 이집트 EGP           74.21
# 인도 INR            15.79
# 인도네시아 IDR          8.01
# 일본 JPY 100     1,119.53
# 중국원화 CNY         170.92
# 체코 CZK            54.05
# 칠레 CLP             1.49
# 카자흐스탄 KZT          2.82
# 카타르 QAR          322.04
# 캐나다 CAD          898.04
# 쿠웨이트 KWD       3,869.33
# 태국 THB            37.89
# 터키 TRY           160.12
# 파키스탄 PKR           7.01
# 폴란드 PLN          322.44
# 필리핀 PHP           24.35
# 헝가리 HUF            4.05
# 호주 AUD           856.59
# 홍콩 HKD           152.45
# dtype: object
