# %% [markdown]
# # 프로젝트: End-to-End OCR

# %% [markdown]
# keras OCR의 Detector class를 이용해서 이미지 내의 문자 위치를 찾아내는 함수를 만들어보도록 하겠습니다.

# %% [markdown]
# #### 진행 순서
# - Recognition model 구현
# - 해당 이미지 내의 문자 찾아내기
# - 단어의 영역을 잘라오기
# - 시각화
# - Recognition model
# - 결과 출력

# %% [markdown]
# ## Recognition model 구현

# %%
import re
import six
import math
import lmdb
import os
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import cv2

from PIL import Image

from tensorflow.keras import layers
from tensorflow.keras.models import Model
from tensorflow.keras.utils import Sequence
from tensorflow.keras import backend as K
from tensorflow.keras.models import load_model
import keras_ocr

BATCH_SIZE = 128
HOME_DIR = os.getenv('HOME')+'/aiffel/ocr'

TRAIN_DATA_PATH = HOME_DIR+'/MJ/MJ_train'
VALID_DATA_PATH = HOME_DIR+'/MJ/MJ_valid'
TEST_DATA_PATH = HOME_DIR+'/MJ/MJ_test'

# %%
path = os.path.join(os.getenv('HOME'),'aiffel/ocr/')
SAMPLE_IMG_PATH = path+'sample.jpg'

# %%
NUMBERS = "0123456789"
ENG_CHAR_UPPER = "ABCDEFGHIJKLMNOPQRSTUVWXYZ"
TARGET_CHARACTERS = ENG_CHAR_UPPER + NUMBERS
print(f"The total number of characters is {len(TARGET_CHARACTERS)}")
# Out:
# The total number of characters is 36

# %% [markdown]
# ### Input Image 확인

# %%
from IPython.display import display

env = lmdb.open(TRAIN_DATA_PATH, max_readers=32, readonly=True, lock=False, readahead=False, meminit=False)
with env.begin(write=False) as txn:
    for index in range(1, 5):
        label_key = 'label-%09d'.encode() % index
        label = txn.get(label_key).decode('utf-8')
        img_key = 'image-%09d'.encode() % index
        imgbuf = txn.get(img_key)
        buf = six.BytesIO()
        buf.write(imgbuf)
        buf.seek(0)
        try:
            img = Image.open(buf).convert('RGB')

        except IOError:
            img = Image.new('RGB', (100, 32))
            label = '-'
        width, height = img.size
        print('original image width:{}, height:{}'.format(width, height))
        
        target_width = min(int(width*32/height), 100)
        target_img_size = (target_width,32 )
        
        print('target_img_size:{}'.format(target_img_size))
        
        img = np.array(img.resize(target_img_size)).transpose(1,0,2)
       
        print('display img shape:{}'.format(img.shape))
        print('label:{}'.format(label))
        display(Image.fromarray(img.transpose(1,0,2).astype(np.uint8)))
# Out:
# original image width:72, height:31
# target_img_size:(74, 32)
# display img shape:(74, 32, 3)
# label:Lube
# <PIL.Image.Image image mode=RGB size=74x32 at 0x7F43382180D0>
# original image width:82, height:31
# target_img_size:(84, 32)
# display img shape:(84, 32, 3)
# label:Spencerian
# <PIL.Image.Image image mode=RGB size=84x32 at 0x7F4338218050>
# original image width:115, height:31
# target_img_size:(100, 32)
# display img shape:(100, 32, 3)
# label:accommodatingly
# <PIL.Image.Image image mode=RGB size=100x32 at 0x7F4338218210>
# original image width:140, height:31
# target_img_size:(100, 32)
# display img shape:(100, 32, 3)
# label:CARPENTER
# <PIL.Image.Image image mode=RGB size=100x32 at 0x7F4338218390>

# %%
class MJDatasetSequence(Sequence):
    def __init__(self, 
                      dataset_path,
                      label_converter,
                      batch_size=1,
                      img_size=(100,32),
                      max_text_len=22,
                      is_train=False,
                      character=''
                ):
        
        self.label_converter = label_converter
        self.batch_size = batch_size
        self.img_size = img_size
        self.max_text_len = max_text_len
        self.character = character
        self.is_train = is_train
        self.divide_length = 100

        self.env = lmdb.open(dataset_path, max_readers=32, readonly=True, lock=False, readahead=False, meminit=False)
        with self.env.begin(write=False) as txn:
            num_samples = int(txn.get('num-samples'.encode()))
            self.num_samples = int(num_samples)
            self.index_list = [index + 1 for index in range(self.num_samples)]
        
    def __len__(self):
        if self.is_train:
            return math.ceil(self.num_samples/self.batch_size/self.divide_length)
        return math.ceil(self.num_samples/self.batch_size/self.divide_length)
    
    def _get_img_label(self, index):
        # Return image array and label in string
        with self.env.begin(write=False) as txn:
            label_key = 'label-%09d'.encode() % index
            label = txn.get(label_key).decode('utf-8')
            img_key = 'image-%09d'.encode() % index
            imgbuf = txn.get(img_key)

            buf = six.BytesIO()
            buf.write(imgbuf)
            buf.seek(0)
            try:
                img = Image.open(buf).convert('RGB')

            except IOError:
                img = Image.new('RGB', self.img_size)
                label = '-'
            width, height = img.size
            
            target_width = min(int(width*self.img_size[1]/height), self.img_size[0])
            target_img_size = (target_width,self.img_size[1] )
            img = np.array(img.resize(target_img_size)).transpose(1,0,2)
            label = label.upper()[:self.max_text_len]
            out_of_char = f'[^{self.character}]'
            label = re.sub(out_of_char, '', label)

        return (img, label)
    
    def __getitem__(self, idx):
        batch_indicies = self.index_list[
            idx*self.batch_size:
            (idx+1)*self.batch_size
        ]
        input_images = np.zeros([self.batch_size, *self.img_size, 3])
        labels = np.zeros([self.batch_size, self.max_text_len], dtype='int64')

        input_length = np.ones([self.batch_size], dtype='int64')*self.max_text_len
        label_length = np.ones([self.batch_size], dtype='int64')

        for i, index in enumerate(batch_indicies):
            img, label = self._get_img_label(index)
            encoded_label = self.label_converter.encode(label)
            width = img.shape[0]
            input_images[i,:width,:,:] = img
            if len(encoded_label) > self.max_text_len:
                continue
            labels[i,0:len(encoded_label)] = encoded_label
            label_length[i] = len(encoded_label)

        inputs = {
            'input_image': input_images,
            'label': labels,
            'input_length': input_length,
            'label_length': label_length,
        }
        outputs = {'ctc': np.zeros([self.batch_size, 1])}
        return inputs, outputs
        
    def on_epoch_end(self):
        self.index_list =  [index + 1 for index in range(self.num_samples)]
        if self.is_train :
            np.random.shuffle(self.index_list)
            return self.index_list

# %% [markdown]
# ### Encode

# %%
class LabelConverter(object):
     """ Convert between text-label and text-index """

     def __init__(self, character):
         self.character = "-" + character
         self.label_map = dict()
         for i, char in enumerate(self.character):
             self.label_map[char] = i

     def encode(self, text):
         encoded_label = []
         for i, char in enumerate(text):
             if i > 0 and char == text[i - 1]:
                 encoded_label.append(0)
             encoded_label.append(self.label_map[char])
         return np.array(encoded_label)

     def decode(self, encoded_label):
         target_characters = list(self.character)
         decoded_label = ""
         for encode in encoded_label:
             decoded_label += self.character[encode]
         return decoded_label

# %%
label_converter = LabelConverter(TARGET_CHARACTERS)

encdoded_text = label_converter.encode('HELLO')
print("Encdoded_text: ", encdoded_text)
decoded_text = label_converter.decode(encdoded_text)
print("Decoded_text: ", decoded_text)
# Out:
# Encdoded_text:  [ 8  5 12  0 12 15]
# Decoded_text:  HEL-LO

# %% [markdown]
# ### Build CRNN model|

# %%
def ctc_lambda_func(args): # CTC loss를 계산하기 위한 Lambda 함수
    labels, y_pred, label_length, input_length = args
    y_pred = y_pred[:, 2:, :]
    return K.ctc_batch_cost(labels, y_pred, input_length, label_length)

# %%
def build_crnn_model(input_shape=(100,32,3), characters=TARGET_CHARACTERS):
    num_chars = len(characters)+2
    image_input = layers.Input(shape=input_shape, dtype='float32', name='input_image')

    # Build CRNN model
    conv = layers.Conv2D(64, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal')(image_input)
    conv = layers.MaxPooling2D(pool_size=(2, 2))(conv)
    conv = layers.Conv2D(128, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal')(conv)
    conv = layers.MaxPooling2D(pool_size=(2, 2))(conv)
    conv = layers.Conv2D(256, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal')(conv)
    conv = layers.Conv2D(256, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal')(conv)
    conv = layers.MaxPooling2D(pool_size=(1, 2))(conv)
    conv = layers.Conv2D(512, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal')(conv)
    conv = layers.BatchNormalization()(conv)
    conv = layers.Conv2D(512, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal')(conv)
    conv = layers.MaxPooling2D(pool_size=(1, 2))(conv)     
    feature = layers.Conv2D(512, (2, 2), activation='relu', kernel_initializer='he_normal')(conv)
    sequnce = layers.Reshape(target_shape=(24, 512))(feature)
    sequnce = layers.Dense(64, activation='relu')(sequnce)
    sequnce = layers.Bidirectional(layers.LSTM(256, return_sequences=True))(sequnce)
    sequnce = layers.Bidirectional(layers.LSTM(256, return_sequences=True))(sequnce)
    y_pred = layers.Dense(num_chars, activation='softmax', name='output')(sequnce)

    labels = layers.Input(shape=[22], dtype='int64', name='label')
    input_length = layers.Input(shape=[1], dtype='int64', name='input_length')
    label_length = layers.Input(shape=[1], dtype='int64', name='label_length')
    loss_out = layers.Lambda(ctc_lambda_func, output_shape=(1,), name="ctc")(
        [labels, y_pred, label_length, input_length]
    )
    model_input = [image_input, labels, input_length, label_length]
    model = Model(
        inputs=model_input,
        outputs=loss_out
    )
    y_func = tf.keras.backend.function(image_input, [y_pred])
    return model, y_func

# %% [markdown]
# ### Train & Inference

# %%
train_set = MJDatasetSequence(TRAIN_DATA_PATH, label_converter, batch_size=BATCH_SIZE, character=TARGET_CHARACTERS, is_train=True)
val_set = MJDatasetSequence(VALID_DATA_PATH, label_converter, batch_size=BATCH_SIZE, character=TARGET_CHARACTERS)

checkpoint_path = HOME_DIR + '/model_checkpoint.hdf5'

model, y_func = build_crnn_model()
sgd = tf.keras.optimizers.Adadelta(lr=0.1, clipnorm=5)
model.compile(loss={'ctc': lambda y_true, y_pred: y_pred}, optimizer=sgd)
ckp = tf.keras.callbacks.ModelCheckpoint(
    checkpoint_path, monitor='val_loss',
    verbose=1, save_best_only=True, save_weights_only=True
)
earlystop = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', min_delta=0, patience=10, verbose=0, mode='min'
)
model.fit(train_set,
        steps_per_epoch=len(val_set),
        epochs=100,
        validation_data=val_set,
        validation_steps=len(val_set),
        callbacks=[ckp])
# Out:
# Epoch 1/100
# 63/63 [==============================] - ETA: 0s - loss: 29.0259
# Epoch 00001: val_loss improved from inf to 27.25791, saving model to /home/aiffel0042/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 9s 144ms/step - loss: 29.0259 - val_loss: 27.2579
# Epoch 2/100
# 63/63 [==============================] - ETA: 0s - loss: 26.5706
# Epoch 00002: val_loss improved from 27.25791 to 26.49338, saving model to /home/aiffel0042/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 9s 136ms/step - loss: 26.5706 - val_loss: 26.4934
# Epoch 3/100
# 63/63 [==============================] - ETA: 0s - loss: 26.3509
# Epoch 00003: val_loss improved from 26.49338 to 26.05050, saving model to /home/aiffel0042/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 8s 127ms/step - loss: 26.3509 - val_loss: 26.0505
# Epoch 4/100
# 63/63 [==============================] - ETA: 0s - loss: 25.7885
# Epoch 00004: val_loss did not improve from 26.05050
# 63/63 [==============================] - 8s 124ms/step - loss: 25.7885 - val_loss: 26.2844
# Epoch 5/100
# 63/63 [==============================] - ETA: 0s - loss: 25.4727
# Epoch 00005: val_loss improved from 26.05050 to 25.56281, saving model to /home/aiffel0042/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 8s 126ms/step - loss: 25.4727 - val_loss: 25.5628
# Epoch 6/100
# 63/63 [==============================] - ETA: 0s - loss: 25.0932
# Epoch 00006: val_loss improved from 25.56281 to 24.81781, saving model to /home/aiffel0042/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 8s 128ms/step - loss: 25.0932 - val_loss: 24.8178
# Epoch 7/100
# 63/63 [==============================] - ETA: 0s - loss: 24.5296
# Epoch 00007: val_loss improved from 24.81781 to 24.22810, saving model to /home/aiffel0042/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 8s 127ms/step - loss: 24.5296 - val_loss: 24.2281
# Epoch 8/100
# 63/63 [==============================] - ETA: 0s - loss: 23.7979
# Epoch 00008: val_loss improved from 24.22810 to 24.12650, saving model to /home/aiffel0042/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 8s 131ms/step - loss: 23.7979 - val_loss: 24.1265
# Epoch 9/100
# 63/63 [==============================] - ETA: 0s - loss: 23.3915
# Epoch 00009: val_loss did not improve from 24.12650
# 63/63 [==============================] - 8s 129ms/step - loss: 23.3915 - val_loss: 24.9958
# Epoch 10/100
# 63/63 [==============================] - ETA: 0s - loss: 22.4517
# Epoch 00010: val_loss did not improve from 24.12650
# 63/63 [==============================] - 8s 125ms/step - loss: 22.4517 - val_loss: 24.7316
# Epoch 11/100
# 63/63 [==============================] - ETA: 0s - loss: 21.1981
# Epoch 00011: val_loss improved from 24.12650 to 22.65368, saving model to /home/aiffel0042/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 8s 128ms/step - loss: 21.1981 - val_loss: 22.6537
# Epoch 12/100
# 63/63 [==============================] - ETA: 0s - loss: 19.5885
# Epoch 00012: val_loss improved from 22.65368 to 22.51416, saving model to /home/aiffel0042/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 8s 128ms/step - loss: 19.5885 - val_loss: 22.5142
# Epoch 13/100
# 63/63 [==============================] - ETA: 0s - loss: 17.6148
# Epoch 00013: val_loss improved from 22.51416 to 17.44264, saving model to /home/aiffel0042/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 8s 126ms/step - loss: 17.6148 - val_loss: 17.4426
# Epoch 14/100
# 63/63 [==============================] - ETA: 0s - loss: 15.4096
# Epoch 00014: val_loss improved from 17.44264 to 15.11796, saving model to /home/aiffel0042/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 9s 138ms/step - loss: 15.4096 - val_loss: 15.1180
# Epoch 15/100
# 63/63 [==============================] - ETA: 0s - loss: 13.6100
# Epoch 00015: val_loss improved from 15.11796 to 15.03995, saving model to /home/aiffel0042/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 8s 126ms/step - loss: 13.6100 - val_loss: 15.0400
# Epoch 16/100
# 63/63 [==============================] - ETA: 0s - loss: 11.9813
# Epoch 00016: val_loss improved from 15.03995 to 12.93469, saving model to /home/aiffel0042/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 8s 126ms/step - loss: 11.9813 - val_loss: 12.9347
# Epoch 17/100
# 63/63 [==============================] - ETA: 0s - loss: 10.9186
# Epoch 00017: val_loss improved from 12.93469 to 11.55250, saving model to /home/aiffel0042/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 8s 132ms/step - loss: 10.9186 - val_loss: 11.5525
# Epoch 18/100
# 63/63 [==============================] - ETA: 0s - loss: 10.0525
# Epoch 00018: val_loss improved from 11.55250 to 10.06076, saving model to /home/aiffel0042/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 8s 123ms/step - loss: 10.0525 - val_loss: 10.0608
# Epoch 19/100
# 63/63 [==============================] - ETA: 0s - loss: 9.3753
# Epoch 00019: val_loss improved from 10.06076 to 10.04842, saving model to /home/aiffel0042/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 8s 128ms/step - loss: 9.3753 - val_loss: 10.0484
# Epoch 20/100
# 63/63 [==============================] - ETA: 0s - loss: 8.9768
# Epoch 00020: val_loss improved from 10.04842 to 9.72373, saving model to /home/aiffel0042/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 8s 129ms/step - loss: 8.9768 - val_loss: 9.7237
# Epoch 21/100
# 63/63 [==============================] - ETA: 0s - loss: 8.3403
# Epoch 00021: val_loss improved from 9.72373 to 8.69065, saving model to /home/aiffel0042/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 9s 135ms/step - loss: 8.3403 - val_loss: 8.6906
# Epoch 22/100
# 63/63 [==============================] - ETA: 0s - loss: 7.7749
# Epoch 00022: val_loss improved from 8.69065 to 8.63050, saving model to /home/aiffel0042/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 8s 132ms/step - loss: 7.7749 - val_loss: 8.6305
# Epoch 23/100
# 63/63 [==============================] - ETA: 0s - loss: 7.6676
# Epoch 00023: val_loss improved from 8.63050 to 7.90164, saving model to /home/aiffel0042/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 8s 132ms/step - loss: 7.6676 - val_loss: 7.9016
# Epoch 24/100
# 63/63 [==============================] - ETA: 0s - loss: 7.2680
# Epoch 00024: val_loss improved from 7.90164 to 7.30895, saving model to /home/aiffel0042/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 8s 131ms/step - loss: 7.2680 - val_loss: 7.3090
# Epoch 25/100
# 63/63 [==============================] - ETA: 0s - loss: 7.1096
# Epoch 00025: val_loss improved from 7.30895 to 7.03605, saving model to /home/aiffel0042/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 8s 123ms/step - loss: 7.1096 - val_loss: 7.0361
# Epoch 26/100
# 63/63 [==============================] - ETA: 0s - loss: 6.7877
# Epoch 00026: val_loss did not improve from 7.03605
# 63/63 [==============================] - 8s 121ms/step - loss: 6.7877 - val_loss: 7.4907
# Epoch 27/100
# 63/63 [==============================] - ETA: 0s - loss: 6.4683
# Epoch 00027: val_loss improved from 7.03605 to 6.87716, saving model to /home/aiffel0042/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 8s 125ms/step - loss: 6.4683 - val_loss: 6.8772
# Epoch 28/100
# 63/63 [==============================] - ETA: 0s - loss: 6.2492
# Epoch 00028: val_loss improved from 6.87716 to 6.71847, saving model to /home/aiffel0042/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 8s 124ms/step - loss: 6.2492 - val_loss: 6.7185
# Epoch 29/100
# 63/63 [==============================] - ETA: 0s - loss: 6.1546
# Epoch 00029: val_loss improved from 6.71847 to 6.39837, saving model to /home/aiffel0042/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 8s 124ms/step - loss: 6.1546 - val_loss: 6.3984
# Epoch 30/100
# 63/63 [==============================] - ETA: 0s - loss: 5.9248
# Epoch 00030: val_loss improved from 6.39837 to 5.97966, saving model to /home/aiffel0042/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 8s 123ms/step - loss: 5.9248 - val_loss: 5.9797
# Epoch 31/100
# 63/63 [==============================] - ETA: 0s - loss: 5.9172
# Epoch 00031: val_loss did not improve from 5.97966
# 63/63 [==============================] - 8s 121ms/step - loss: 5.9172 - val_loss: 6.3211
# Epoch 32/100
# 63/63 [==============================] - ETA: 0s - loss: 5.7967
# Epoch 00032: val_loss did not improve from 5.97966
# 63/63 [==============================] - 8s 121ms/step - loss: 5.7967 - val_loss: 6.2054
# Epoch 33/100
# 63/63 [==============================] - ETA: 0s - loss: 5.6537
# Epoch 00033: val_loss improved from 5.97966 to 5.90210, saving model to /home/aiffel0042/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 8s 123ms/step - loss: 5.6537 - val_loss: 5.9021
# Epoch 34/100
# 63/63 [==============================] - ETA: 0s - loss: 5.5279
# Epoch 00034: val_loss improved from 5.90210 to 5.51572, saving model to /home/aiffel0042/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 8s 123ms/step - loss: 5.5279 - val_loss: 5.5157
# Epoch 35/100
# 63/63 [==============================] - ETA: 0s - loss: 5.3541
# Epoch 00035: val_loss improved from 5.51572 to 5.40395, saving model to /home/aiffel0042/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 8s 123ms/step - loss: 5.3541 - val_loss: 5.4040
# Epoch 36/100
# 63/63 [==============================] - ETA: 0s - loss: 5.2240
# Epoch 00036: val_loss did not improve from 5.40395
# 63/63 [==============================] - 8s 121ms/step - loss: 5.2240 - val_loss: 5.7242
# Epoch 37/100
# 63/63 [==============================] - ETA: 0s - loss: 5.2410
# Epoch 00037: val_loss did not improve from 5.40395
# 63/63 [==============================] - 8s 121ms/step - loss: 5.2410 - val_loss: 5.4835
# Epoch 38/100
# 63/63 [==============================] - ETA: 0s - loss: 4.9352
# Epoch 00038: val_loss improved from 5.40395 to 5.21014, saving model to /home/aiffel0042/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 8s 123ms/step - loss: 4.9352 - val_loss: 5.2101
# Epoch 39/100
# 63/63 [==============================] - ETA: 0s - loss: 4.8611
# Epoch 00039: val_loss improved from 5.21014 to 5.05022, saving model to /home/aiffel0042/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 8s 123ms/step - loss: 4.8611 - val_loss: 5.0502
# Epoch 40/100
# 63/63 [==============================] - ETA: 0s - loss: 4.8022
# Epoch 00040: val_loss did not improve from 5.05022
# 63/63 [==============================] - 8s 121ms/step - loss: 4.8022 - val_loss: 5.0795
# Epoch 41/100
# 63/63 [==============================] - ETA: 0s - loss: 4.7395
# Epoch 00041: val_loss improved from 5.05022 to 4.96962, saving model to /home/aiffel0042/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 8s 123ms/step - loss: 4.7395 - val_loss: 4.9696
# Epoch 42/100
# 63/63 [==============================] - ETA: 0s - loss: 4.7306
# Epoch 00042: val_loss improved from 4.96962 to 4.65226, saving model to /home/aiffel0042/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 8s 126ms/step - loss: 4.7306 - val_loss: 4.6523
# Epoch 43/100
# 63/63 [==============================] - ETA: 0s - loss: 4.6304
# Epoch 00043: val_loss did not improve from 4.65226
# 63/63 [==============================] - 8s 121ms/step - loss: 4.6304 - val_loss: 4.7130
# Epoch 44/100
# 63/63 [==============================] - ETA: 0s - loss: 4.5789
# Epoch 00044: val_loss did not improve from 4.65226
# 63/63 [==============================] - 8s 121ms/step - loss: 4.5789 - val_loss: 4.8133
# Epoch 45/100
# 63/63 [==============================] - ETA: 0s - loss: 4.5438
# Epoch 00045: val_loss did not improve from 4.65226
# 63/63 [==============================] - 8s 121ms/step - loss: 4.5438 - val_loss: 4.6595
# Epoch 46/100
# 63/63 [==============================] - ETA: 0s - loss: 4.3353
# Epoch 00046: val_loss did not improve from 4.65226
# 63/63 [==============================] - 8s 121ms/step - loss: 4.3353 - val_loss: 4.6601
# Epoch 47/100
# 63/63 [==============================] - ETA: 0s - loss: 4.4259
# Epoch 00047: val_loss improved from 4.65226 to 4.51766, saving model to /home/aiffel0042/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 8s 123ms/step - loss: 4.4259 - val_loss: 4.5177
# Epoch 48/100
# 63/63 [==============================] - ETA: 0s - loss: 4.2659
# Epoch 00048: val_loss improved from 4.51766 to 4.49619, saving model to /home/aiffel0042/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 8s 123ms/step - loss: 4.2659 - val_loss: 4.4962
# Epoch 49/100
# 63/63 [==============================] - ETA: 0s - loss: 4.2901
# Epoch 00049: val_loss did not improve from 4.49619
# 63/63 [==============================] - 8s 121ms/step - loss: 4.2901 - val_loss: 4.5353
# Epoch 50/100
# 63/63 [==============================] - ETA: 0s - loss: 4.0928
# Epoch 00050: val_loss improved from 4.49619 to 4.25058, saving model to /home/aiffel0042/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 8s 126ms/step - loss: 4.0928 - val_loss: 4.2506
# Epoch 51/100
# 63/63 [==============================] - ETA: 0s - loss: 4.1097
# Epoch 00051: val_loss did not improve from 4.25058
# 63/63 [==============================] - 8s 121ms/step - loss: 4.1097 - val_loss: 4.3482
# Epoch 52/100
# 63/63 [==============================] - ETA: 0s - loss: 4.1954
# Epoch 00052: val_loss improved from 4.25058 to 4.13436, saving model to /home/aiffel0042/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 8s 123ms/step - loss: 4.1954 - val_loss: 4.1344
# Epoch 53/100
# 63/63 [==============================] - ETA: 0s - loss: 4.2545
# Epoch 00053: val_loss did not improve from 4.13436
# 63/63 [==============================] - 8s 121ms/step - loss: 4.2545 - val_loss: 4.2640
# Epoch 54/100
# 63/63 [==============================] - ETA: 0s - loss: 4.0086
# Epoch 00054: val_loss improved from 4.13436 to 4.07588, saving model to /home/aiffel0042/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 8s 123ms/step - loss: 4.0086 - val_loss: 4.0759
# Epoch 55/100
# 63/63 [==============================] - ETA: 0s - loss: 4.0325
# Epoch 00055: val_loss did not improve from 4.07588
# 63/63 [==============================] - 8s 121ms/step - loss: 4.0325 - val_loss: 4.2268
# Epoch 56/100
# 63/63 [==============================] - ETA: 0s - loss: 3.9854
# Epoch 00056: val_loss improved from 4.07588 to 3.97034, saving model to /home/aiffel0042/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 8s 123ms/step - loss: 3.9854 - val_loss: 3.9703
# Epoch 57/100
# 63/63 [==============================] - ETA: 0s - loss: 3.7817
# Epoch 00057: val_loss improved from 3.97034 to 3.93752, saving model to /home/aiffel0042/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 8s 123ms/step - loss: 3.7817 - val_loss: 3.9375
# Epoch 58/100
# 63/63 [==============================] - ETA: 0s - loss: 3.9318
# Epoch 00058: val_loss did not improve from 3.93752
# 63/63 [==============================] - 8s 121ms/step - loss: 3.9318 - val_loss: 3.9872
# Epoch 59/100
# 63/63 [==============================] - ETA: 0s - loss: 3.9338
# Epoch 00059: val_loss improved from 3.93752 to 3.93132, saving model to /home/aiffel0042/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 8s 122ms/step - loss: 3.9338 - val_loss: 3.9313
# Epoch 60/100
# 63/63 [==============================] - ETA: 0s - loss: 3.7084
# Epoch 00060: val_loss improved from 3.93132 to 3.88615, saving model to /home/aiffel0042/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 8s 123ms/step - loss: 3.7084 - val_loss: 3.8861
# Epoch 61/100
# 63/63 [==============================] - ETA: 0s - loss: 3.6953
# Epoch 00061: val_loss improved from 3.88615 to 3.88540, saving model to /home/aiffel0042/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 8s 124ms/step - loss: 3.6953 - val_loss: 3.8854
# Epoch 62/100
# 63/63 [==============================] - ETA: 0s - loss: 3.6790
# Epoch 00062: val_loss did not improve from 3.88540
# 63/63 [==============================] - 8s 122ms/step - loss: 3.6790 - val_loss: 3.9581
# Epoch 63/100
# 63/63 [==============================] - ETA: 0s - loss: 3.5886
# Epoch 00063: val_loss improved from 3.88540 to 3.82544, saving model to /home/aiffel0042/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 8s 124ms/step - loss: 3.5886 - val_loss: 3.8254
# Epoch 64/100
# 63/63 [==============================] - ETA: 0s - loss: 3.6889
# Epoch 00064: val_loss improved from 3.82544 to 3.72028, saving model to /home/aiffel0042/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 8s 123ms/step - loss: 3.6889 - val_loss: 3.7203
# Epoch 65/100
# 63/63 [==============================] - ETA: 0s - loss: 3.6386
# Epoch 00065: val_loss improved from 3.72028 to 3.68626, saving model to /home/aiffel0042/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 8s 123ms/step - loss: 3.6386 - val_loss: 3.6863
# Epoch 66/100
# 63/63 [==============================] - ETA: 0s - loss: 3.5663
# Epoch 00066: val_loss did not improve from 3.68626
# 63/63 [==============================] - 8s 122ms/step - loss: 3.5663 - val_loss: 3.7807
# Epoch 67/100
# 63/63 [==============================] - ETA: 0s - loss: 3.6931
# Epoch 00067: val_loss improved from 3.68626 to 3.55572, saving model to /home/aiffel0042/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 8s 123ms/step - loss: 3.6931 - val_loss: 3.5557
# Epoch 68/100
# 63/63 [==============================] - ETA: 0s - loss: 3.5561
# Epoch 00068: val_loss did not improve from 3.55572
# 63/63 [==============================] - 8s 120ms/step - loss: 3.5561 - val_loss: 3.7262
# Epoch 69/100
# 63/63 [==============================] - ETA: 0s - loss: 3.4593
# Epoch 00069: val_loss did not improve from 3.55572
# 63/63 [==============================] - 8s 122ms/step - loss: 3.4593 - val_loss: 3.8182
# Epoch 70/100
# 63/63 [==============================] - ETA: 0s - loss: 3.4649
# Epoch 00070: val_loss improved from 3.55572 to 3.46256, saving model to /home/aiffel0042/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 8s 123ms/step - loss: 3.4649 - val_loss: 3.4626
# Epoch 71/100
# 63/63 [==============================] - ETA: 0s - loss: 3.4059
# Epoch 00071: val_loss improved from 3.46256 to 3.45515, saving model to /home/aiffel0042/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 8s 122ms/step - loss: 3.4059 - val_loss: 3.4551
# Epoch 72/100
# 63/63 [==============================] - ETA: 0s - loss: 3.4027
# Epoch 00072: val_loss did not improve from 3.45515
# 63/63 [==============================] - 8s 121ms/step - loss: 3.4027 - val_loss: 3.6150
# Epoch 73/100
# 63/63 [==============================] - ETA: 0s - loss: 3.3844
# Epoch 00073: val_loss did not improve from 3.45515
# 63/63 [==============================] - 8s 121ms/step - loss: 3.3844 - val_loss: 3.5855
# Epoch 74/100
# 63/63 [==============================] - ETA: 0s - loss: 3.3432
# Epoch 00074: val_loss did not improve from 3.45515
# 63/63 [==============================] - 8s 121ms/step - loss: 3.3432 - val_loss: 3.4803
# Epoch 75/100
# 63/63 [==============================] - ETA: 0s - loss: 3.4162
# Epoch 00075: val_loss improved from 3.45515 to 3.42364, saving model to /home/aiffel0042/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 8s 124ms/step - loss: 3.4162 - val_loss: 3.4236
# Epoch 76/100
# 63/63 [==============================] - ETA: 0s - loss: 3.2964
# Epoch 00076: val_loss improved from 3.42364 to 3.33160, saving model to /home/aiffel0042/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 8s 123ms/step - loss: 3.2964 - val_loss: 3.3316
# Epoch 77/100
# 63/63 [==============================] - ETA: 0s - loss: 3.3188
# Epoch 00077: val_loss improved from 3.33160 to 3.29987, saving model to /home/aiffel0042/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 8s 123ms/step - loss: 3.3188 - val_loss: 3.2999
# Epoch 78/100
# 63/63 [==============================] - ETA: 0s - loss: 3.2148
# Epoch 00078: val_loss did not improve from 3.29987
# 63/63 [==============================] - 8s 121ms/step - loss: 3.2148 - val_loss: 3.4074
# Epoch 79/100
# 63/63 [==============================] - ETA: 0s - loss: 3.2394
# Epoch 00079: val_loss did not improve from 3.29987
# 63/63 [==============================] - 8s 122ms/step - loss: 3.2394 - val_loss: 3.3586
# Epoch 80/100
# 63/63 [==============================] - ETA: 0s - loss: 3.2231
# Epoch 00080: val_loss did not improve from 3.29987
# 63/63 [==============================] - 8s 121ms/step - loss: 3.2231 - val_loss: 3.3180
# Epoch 81/100
# 63/63 [==============================] - ETA: 0s - loss: 3.1714
# Epoch 00081: val_loss did not improve from 3.29987
# 63/63 [==============================] - 8s 120ms/step - loss: 3.1714 - val_loss: 3.3114
# Epoch 82/100
# 63/63 [==============================] - ETA: 0s - loss: 3.1849
# Epoch 00082: val_loss improved from 3.29987 to 3.23914, saving model to /home/aiffel0042/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 8s 123ms/step - loss: 3.1849 - val_loss: 3.2391
# Epoch 83/100
# 63/63 [==============================] - ETA: 0s - loss: 3.1605
# Epoch 00083: val_loss improved from 3.23914 to 3.19159, saving model to /home/aiffel0042/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 8s 123ms/step - loss: 3.1605 - val_loss: 3.1916
# Epoch 84/100
# 63/63 [==============================] - ETA: 0s - loss: 3.1666
# Epoch 00084: val_loss improved from 3.19159 to 3.16046, saving model to /home/aiffel0042/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 8s 123ms/step - loss: 3.1666 - val_loss: 3.1605
# Epoch 85/100
# 63/63 [==============================] - ETA: 0s - loss: 3.2345
# Epoch 00085: val_loss did not improve from 3.16046
# 63/63 [==============================] - 8s 122ms/step - loss: 3.2345 - val_loss: 3.2541
# Epoch 86/100
# 63/63 [==============================] - ETA: 0s - loss: 3.0602
# Epoch 00086: val_loss did not improve from 3.16046
# 63/63 [==============================] - 8s 120ms/step - loss: 3.0602 - val_loss: 3.2663
# Epoch 87/100
# 63/63 [==============================] - ETA: 0s - loss: 3.0400
# Epoch 00087: val_loss improved from 3.16046 to 3.13910, saving model to /home/aiffel0042/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 8s 125ms/step - loss: 3.0400 - val_loss: 3.1391
# Epoch 88/100
# 63/63 [==============================] - ETA: 0s - loss: 3.2240
# Epoch 00088: val_loss improved from 3.13910 to 3.13220, saving model to /home/aiffel0042/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 8s 123ms/step - loss: 3.2240 - val_loss: 3.1322
# Epoch 89/100
# 63/63 [==============================] - ETA: 0s - loss: 3.0650
# Epoch 00089: val_loss improved from 3.13220 to 3.12929, saving model to /home/aiffel0042/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 8s 123ms/step - loss: 3.0650 - val_loss: 3.1293
# Epoch 90/100
# 63/63 [==============================] - ETA: 0s - loss: 3.0647
# Epoch 00090: val_loss did not improve from 3.12929
# 63/63 [==============================] - 8s 124ms/step - loss: 3.0647 - val_loss: 3.2013
# Epoch 91/100
# 63/63 [==============================] - ETA: 0s - loss: 2.9038
# Epoch 00091: val_loss did not improve from 3.12929
# 63/63 [==============================] - 8s 120ms/step - loss: 2.9038 - val_loss: 3.1370
# Epoch 92/100
# 63/63 [==============================] - ETA: 0s - loss: 3.0371
# Epoch 00092: val_loss improved from 3.12929 to 3.07522, saving model to /home/aiffel0042/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 8s 121ms/step - loss: 3.0371 - val_loss: 3.0752
# Epoch 93/100
# 63/63 [==============================] - ETA: 0s - loss: 3.0233
# Epoch 00093: val_loss did not improve from 3.07522
# 63/63 [==============================] - 7s 119ms/step - loss: 3.0233 - val_loss: 3.1415
# Epoch 94/100
# 63/63 [==============================] - ETA: 0s - loss: 2.9897
# Epoch 00094: val_loss improved from 3.07522 to 2.98099, saving model to /home/aiffel0042/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 8s 122ms/step - loss: 2.9897 - val_loss: 2.9810
# Epoch 95/100
# 63/63 [==============================] - ETA: 0s - loss: 2.9704
# Epoch 00095: val_loss improved from 2.98099 to 2.97291, saving model to /home/aiffel0042/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 8s 121ms/step - loss: 2.9704 - val_loss: 2.9729
# Epoch 96/100
# 63/63 [==============================] - ETA: 0s - loss: 2.9718
# Epoch 00096: val_loss did not improve from 2.97291
# 63/63 [==============================] - 8s 119ms/step - loss: 2.9718 - val_loss: 2.9822
# Epoch 97/100
# 63/63 [==============================] - ETA: 0s - loss: 2.8035
# Epoch 00097: val_loss did not improve from 2.97291
# 63/63 [==============================] - 8s 120ms/step - loss: 2.8035 - val_loss: 2.9878
# Epoch 98/100
# 63/63 [==============================] - ETA: 0s - loss: 2.8621
# Epoch 00098: val_loss improved from 2.97291 to 2.89807, saving model to /home/aiffel0042/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 8s 122ms/step - loss: 2.8621 - val_loss: 2.8981
# Epoch 99/100
# 63/63 [==============================] - ETA: 0s - loss: 2.9219
# Epoch 00099: val_loss did not improve from 2.89807
# 63/63 [==============================] - 8s 119ms/step - loss: 2.9219 - val_loss: 3.0106
# Epoch 100/100
# 63/63 [==============================] - ETA: 0s - loss: 2.8995
# Epoch 00100: val_loss did not improve from 2.89807
# 63/63 [==============================] - 8s 119ms/step - loss: 2.8995 - val_loss: 2.9859

# %% [markdown]
# ### 해당 이미지 내의 문자 찾아내기

# %%
def detect_text(img_path):
    pipeline = keras_ocr.pipeline.Pipeline()
    
    images = keras_ocr.tools.read(img_path)
    predictions = pipeline.recognize([img_path])
    
    result_img = keras_ocr.tools.drawAnnotations(image=images, predictions=predictions[0])

    cropped_imgs = []
    revised_boxes = []
    for _, box in predictions[0]:
        revised_boxes.append(box)
    boxes = revised_boxes

    crop_box =[]
    for box in boxes:
        cropped_imgs.append(keras_ocr.tools.warpBox(image=images, box=box))


    return result_img, cropped_imgs

# %% [markdown]
# ### 단어의 영역을 잘라오기

# %%
img_pil, cropped_img = detect_text(SAMPLE_IMG_PATH)
display(img_pil)
# Out:
# Looking for /home/aiffel0042/.keras-ocr/craft_mlt_25k.h5
# WARNING:tensorflow:From /home/aiffel0042/anaconda3/envs/aiffel/lib/python3.7/site-packages/tensorflow/python/util/dispatch.py:201: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# Looking for /home/aiffel0042/.keras-ocr/crnn_kurapan.h5
# /home/aiffel0042/anaconda3/envs/aiffel/lib/python3.7/site-packages/keras_ocr/tools.py:166: MatplotlibDeprecationWarning: The 's' parameter of annotate() has been renamed 'text' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
#   horizontalalignment='right' if side == 'left' else 'left')
# <AxesSubplot:>

# %% [markdown]
# ### 시각화

# %%
plt.subplot(2, 1, 1)
plt.imshow(cropped_img[0])
plt.axis('off')

plt.subplot(2, 1, 2)
plt.imshow(cropped_img[1])
plt.axis('off')
# Out:
# (-0.5, 420.5, 145.5, -0.5)

# %% [markdown]
# ### 결과 출력

# %%
def recognize_img(pil_img, input_img_size=(100,32)):
    img90 = cv2.rotate(pil_img, cv2.ROTATE_90_COUNTERCLOCKWISE)
    img_flip = cv2.flip(img90, 0)
    pil_img = cv2.resize(img_flip, (32, 100), interpolation = cv2.INTER_CUBIC)
    img = pil_img.reshape(1, 100, 32, 3)
    output = model_pred.predict(img)
    result = decode_predict_ctc(output, chars="-"+TARGET_CHARACTERS)[0].replace('-','')
    print("Result: \t", result)
    display(Image.fromarray(img[0].transpose(1,0,2).astype(np.uint8)))

# %%
for _img in cropped_img:
    recognize_img(_img)
# Out:
# Result: 	 YFYS99999999999999999999
# <PIL.Image.Image image mode=RGB size=100x32 at 0x7F362D57AAD0>
# Result: 	 SLEEPER9999999999999999
# <PIL.Image.Image image mode=RGB size=100x32 at 0x7F362C6B6350>

# %% [markdown]
# ### Report

# %% [markdown]
# 추론 결과 아래 이미지니 SLEEPER은 제대로 학습이 됐습니다.
# 하지만 위의 그림은 우리가 학습시킨 데이터로는 잘 번역이 안되는 것 같습니다.
